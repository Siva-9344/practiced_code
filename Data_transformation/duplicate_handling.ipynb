# %%
import pandas as pd
file_path = "C:/Users//Sivaraman//Desktop//study//data analytics//Data (for practice)//bank_details_1.csv"
df = pd.read_csv(file_path)
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
print(backup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(backup)
#
# NameError: name 'backup' is not defined

# %%
backup = df.copy()
print(backup)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 9996     False
# 9997      True
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
dis = df[df.duplicated(keep = False)]
print(dis)
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 0     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0        Onio          502   France  Female  42.0     8.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 11    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 150   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 152   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# ...

# %%
print(dis.count())
# Out:
# CustomerId       19
# Name             19
# CreditScore      19
# Country          19
# Gender           19
# Age              19
# Tenure           19
# Balance          19
# NumOfProducts    19
# Salary           19
# Exited           19
# dtype: int64

# %%
rem_dup_from_dis = dis.drop_duplicates().reset_index()
print(rem_dup_from_dis)
# Out:
#    index  CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      0  15634602.0    Hargrave          619   France  Female  42.0     2.0
# 1      2  15634602.0        Onio          502   France  Female  42.0     8.0
# 2     11  15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 3    150  15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 4    152  15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 5   9990  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 6   9996  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
#      Balance  NumOfProducts     Salary  Exited
# 0       0.00            1.0  101348.88     1.0
# 1  159660.80            3.0  112542.58     1.0
# 2  142051.07            2.0   76390.01     0.0
# 3       0.00            2.0   89520.75     0.0
# 4       0.00            2.0  180800.42     0.0
# 5   35016.60            1.0   53667.08     0.0
# ...

# %%
last = dis.drop_duplicates(keep = 'last').reset_index()
print(last)
# Out:
#    index  CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      1  15634602.0    Hargrave          619   France  Female  42.0     2.0
# 1      3  15634602.0        Onio          502   France  Female  42.0     8.0
# 2     13  15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 3    151  15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 4    157  15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 5   9991  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 6   9997  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
#      Balance  NumOfProducts     Salary  Exited
# 0       0.00            1.0  101348.88     1.0
# 1  159660.80            3.0  112542.58     1.0
# 2  142051.07            2.0   76390.01     0.0
# 3       0.00            2.0   89520.75     0.0
# 4       0.00            2.0  180800.42     0.0
# 5   35016.60            1.0   53667.08     0.0
# ...

# %%
df.duplicated(subset = ['CustomerId'])
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 9996     False
# 9997      True
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
name = df.duplicated(subset = ['Name'], keep = False)

# %%
name = df.duplicatde(subset = ['Name'], keep = False)
print(name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12680\365798488.py in ?()
# ----> 1 name = df.duplicatde(subset = ['Name'], keep = False)
#       2 print(name)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicatde'

# %%
name = df.duplicated(subset = ['Name'], keep = False)
print(name)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 9996      True
# 9997      True
# 9998      True
# 9999      True
# 10000    False
# Length: 10001, dtype: bool

# %%
name = df[df.duplicated(subset = ['Name'], keep = False)]
print(name)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0     15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1     15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0       Onio          502   France  Female  42.0     8.0
# 3     15634602.0       Onio          502   France  Female  42.0     8.0
# 4     15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...          ...        ...          ...      ...     ...   ...     ...
# 9995  15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996  15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997  15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998  15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999  15628319.0     Walker          792   France  Female  28.0     4.0
#
#         Balance  NumOfProducts     Salary  Exited
# 0          0.00            1.0  101348.88     1.0
# ...

# %%
name = df[df.duplicated(subset = ['Name'])]
print(name)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0   Hargrave          619   France  Female  42.0     2.0
# 3     15634602.0       Onio          502   France  Female  42.0     8.0
# 7     15574012.0   Bartlett          376  Germany  Female  29.0     4.0
# 8     15574012.0   Bartlett          501   France    Male  44.0     4.0
# 9     15574012.0   Bartlett          684   France    Male  27.0     2.0
# ...          ...        ...          ...      ...     ...   ...     ...
# 9995  15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996  15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997  15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998  15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999  15628319.0     Walker          792   France  Female  28.0     4.0
#
#         Balance  NumOfProducts     Salary  Exited
# 1          0.00            1.0  101348.88     1.0
# ...

# %%
name = df[df.duplicated(subset = ['CustomerId'], keep = 'False')]['Name'].unique()
print(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 name = df[df.duplicated(subset = ['CustomerId'], keep = 'False')]['Name'].unique()
#       2 print(name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:6954, in DataFrame.duplicated(self, subset, keep)
#    6950     raise KeyError(Index(diff))
#    6952 if len(subset) == 1 and self.columns.is_unique:
#    6953     # GH#45236 This is faster than get_group_index below
# -> 6954     result = self[subset[0]].duplicated(keep)
#    6955     result.name = None
#    6956 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:2604, in Series.duplicated(self, keep)
#    2528 def duplicated(self, keep: DropKeep = "first") -> Series:
#    2529     """
#    2530     Indicate duplicate Series values.
#    2531
#    (...)
# ...

# %%
name = df[df.duplicated(subset = ['Name'], keep = False)]['Name'].unique()
print(name)
# Out:
# ['Hargrave' 'Onio' 'Mitchell' ... 'Michael' 'Bryan' 'Chukwujekwu']

# %%
df['is_duplicated'] = df.duplicated(subset = ['Name'], keep = False)

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
rem_dup = df.drop_duplicates(subset = ['Name'], keep = False)
print(rem_dup)
# Out:
#        CustomerId       Name  CreditScore  Country Gender   Age  Tenure  \
# 15     15643966.0    Goforth          616  Germany   Male  45.0     3.0
# 16     15737452.0      Romeo          653  Germany   Male  58.0     1.0
# 18     15661507.0    Muldrow          587    Spain   Male  45.0     6.0
# 23     15725737.0     Mosman          669   France   Male  46.0     3.0
# 38     15717426.0  Armstrong          850   France   Male  36.0     7.0
# ...           ...        ...          ...      ...    ...   ...     ...
# 9952   15696355.0  Cleveland          724  Germany   Male  37.0     6.0
# 9955   15611338.0  Kashiwagi          714    Spain   Male  29.0     4.0
# 9961   15566543.0   Aldridge          573    Spain   Male  44.0     9.0
# 9981   15672754.0   Burbidge          498  Germany   Male  42.0     3.0
# 10000         NaN        NaN      6505288      NaN    NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
print(rem_dup.count())
# Out:
# CustomerId       1557
# Name             1557
# CreditScore      1558
# Country          1557
# Gender           1557
# Age              1557
# Tenure           1557
# Balance          1557
# NumOfProducts    1557
# Salary           1557
# Exited           1557
# is_duplicated    1558
# dtype: int64

# %%
rem_dup = df.drop_duplicates(subset = ['CustomerId'], keep = False)
print(rem_dup)
print(rem_dup.count())
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# 15     15643966.0    Goforth          616  Germany    Male  45.0     3.0
# 16     15737452.0      Romeo          653  Germany    Male  58.0     1.0
# 17     15788218.0  Henderson          549    Spain  Female  24.0     9.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9994   15719294.0       Wood          800   France  Female  29.0     2.0
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
rem_dup = df[df.drop_duplicates(subset = ['Name','CustomerId'], keep = False)]
print(rem_dup)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12680\1159716719.py in ?()
# ----> 1 rem_dup = df[df.drop_duplicates(subset = ['Name','CustomerId'], keep = False)]
#       2 print(rem_dup)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10980                         stacklevel=2,
#   10981                     )
#   10982
# ...

# %%
rem_dup = df.drop_duplicates(subset = ['Name', 'CustomerId'], keep = 'first', inplace = True)
print(rem_dup)
# Out:
# None

# %%
rem_dup = df.drop_duplicates(subset = ['Name', 'CustomerId'], keep = 'first')
print(rem_dup)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 6      15574012.0   Bartlett          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.drop_duplicates(subset = ['Name'])
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 6      15574012.0   Bartlett          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9952   15696355.0  Cleveland          724  Germany    Male  37.0     6.0
# 9955   15611338.0  Kashiwagi          714    Spain    Male  29.0     4.0
# 9961   15566543.0   Aldridge          573    Spain    Male  44.0     9.0
# 9981   15672754.0   Burbidge          498  Germany    Male  42.0     3.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.drop_duplicates(subset = ['CustomerId'])
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 11     15737173.0    Andrews          528    Spain    Male  24.0     3.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df['is_duplicated'] = df.duplicated(subset = ['CustomerId'], keep = False)

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 6      15574012.0   Bartlett          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.duplicated(subset = ['CustomerId'])
# Out:
# 0        False
# 2         True
# 4        False
# 5        False
# 6         True
#          ...
# 9995     False
# 9996     False
# 9998     False
# 9999     False
# 10000    False
# Length: 9985, dtype: bool

# %%
df.drop_duplicates(subset = ['CustomerId'])
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 11     15737173.0    Andrews          528    Spain    Male  24.0     3.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df['is_duplicated'] = df.duplicated(subset = ['CustomerId'])

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 6      15574012.0   Bartlett          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.drop_duplicates(subset = ['CustomerId'])
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 11     15737173.0    Andrews          528    Spain    Male  24.0     3.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.duplicated(subset = ['CustomerId']).sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(subset = ['CustomerId'])
df.duplicated(subset = ['CustomerId']).sum()
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 6      15574012.0   Bartlett          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.drop_duplicates(subset = ['CustomerId'], inplace = True)

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 11     15737173.0    Andrews          528    Spain    Male  24.0     3.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
df.duplicated(subset = ['CustomerId']).sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset = ['CustomerId', 'Name'])
# Out:
# 0        False
# 4        False
# 5        False
# 11       False
# 14       False
#          ...
# 9995     False
# 9996     False
# 9998     False
# 9999     False
# 10000    False
# Length: 9983, dtype: bool

# %%
df.duplicated(subset = ['CustomerId', 'Name'])
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# 5      15574012.0        Chu          645    Spain    Male  44.0     8.0
# 11     15737173.0    Andrews          528    Spain    Male  24.0     3.0
# 14     15600882.0      Scott          528    Spain  Female  35.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   15606229.0   Obijiaku          771   France    Male  39.0     5.0
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  is_duplicated
# ...

# %%
dup_row = df[df.duplicated(subset = ['CustomerId', 'Name'], keep = False)]
print(dub_row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 dup_row = df[df.duplicated(subset = ['CustomerId', 'Name'], keep = False)]
# ----> 2 print(dub_row)
#
# NameError: name 'dub_row' is not defined

# %%
dup_row = df[df.duplicated(subset = ['CustomerId', 'Name'], keep = False)]
print(dup_row)
# Out:
# Empty DataFrame
# Columns: [CustomerId, Name, CreditScore, Country, Gender, Age, Tenure, Balance, NumOfProducts, Salary, Exited, is_duplicated]
# Index: []

# %%
df[df.duplicated(subset = ['CustomerId', 'Name'], keep = False)]
# Out:
# Empty DataFrame
# Columns: [CustomerId, Name, CreditScore, Country, Gender, Age, Tenure, Balance, NumOfProducts, Salary, Exited, is_duplicated]
# Index: []

# %%
df[duplicated(subset = ['CustomerId'])]>sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df[duplicated(subset = ['CustomerId'])]>sum()
#
# NameError: name 'duplicated' is not defined

# %%
df[df.duplicated(subset = ['CustomerId']).sum()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: np.int64(0)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ...

# %%
df[df.duplicated(subset = ['CustomerId'])].sum()
# Out:
# CustomerId       0.0
# Name               0
# CreditScore        0
# Country            0
# Gender             0
# Age              0.0
# Tenure           0.0
# Balance          0.0
# NumOfProducts    0.0
# Salary           0.0
# Exited           0.0
# is_duplicated      0
# dtype: object

# %%
print(backup)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
backup.duplicated().sum()
# Out:
# np.int64(12)

# %%
backup[backup.duplicated(subset = ['CustomerId', 'Name'])].sum()
# Out:
# CustomerId                                             251116636.0
# Name             HargraveOnioBartlettBartlettBartlettBartlettAn...
# CreditScore                                                   9830
# Country          FranceFranceGermanyFranceFranceFranceSpainSpai...
# Gender           FemaleFemaleFemaleMaleMaleMaleMaleMaleFemaleMa...
# Age                                                          573.0
# Tenure                                                        92.0
# Balance                                                  1077349.1
# NumOfProducts                                                 31.0
# Salary                                                  1861755.41
# Exited                                                         3.0
# dtype: object

# %%
backup[backup.duplicated(subset = ['CustomerId', 'Name'], keep = False)].sum()
# Out:
# CustomerId                                             376527707.0
# Name             HargraveHargraveOnioOnioBartlettBartlettBartle...
# CreditScore                                                  15001
# Country          FranceFranceFranceFranceFranceGermanyFranceFra...
# Gender           FemaleFemaleFemaleFemaleMaleFemaleMaleMaleMale...
# Age                                                          873.0
# Tenure                                                       140.0
# Balance                                                 1471447.18
# NumOfProducts                                                 45.0
# Salary                                                   2587787.7
# Exited                                                         5.0
# dtype: object

# %%
backup[backup.duplicated(subset = ['CustomerId', 'Name'], keep = False)]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 0     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0        Onio          502   France  Female  42.0     8.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 6     15574012.0    Bartlett          822   France    Male  50.0     7.0
# 7     15574012.0    Bartlett          376  Germany  Female  29.0     4.0
# 8     15574012.0    Bartlett          501   France    Male  44.0     4.0
# 9     15574012.0    Bartlett          684   France    Male  27.0     2.0
# 10    15574012.0    Bartlett          528   France    Male  31.0     6.0
# 11    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# ...

# %%
print(backup1a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(backup1a)
#
# NameError: name 'backup1a' is not defined

# %%
print(backup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(backup)
#
# NameError: name 'backup' is not defined

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

file_path = "C:\\Users\\Sivaraman\\Desktop\\study\\data analytics\\Data (for practice)\\bank_details_1.csv"

df = pd.read_csv(file_path)
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 9996     False
# 9997      True
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
df[df.duplicated(keep = False)]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 0     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0        Onio          502   France  Female  42.0     8.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 11    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 150   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 152   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# ...

# %%
df[df.duplicated()]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 155   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 156   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 157   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 9991  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 9997  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
# ...

# %%
backup = df.copy()
print(backup)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df[df.drop_duplicates(), reset_index = True]
# Out:
#   Cell In[9], line 1
#     df[df.drop_duplicates(), reset_index = True]
#                              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df[df.drop_duplicates()] reset_index = True
# Out:
#   Cell In[10], line 1
#     df[df.drop_duplicates()] reset_index = True
#                              ^
# SyntaxError: invalid syntax

# %%
df[df.drop_duplicates(keep = True, reset_index = True)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[df.drop_duplicates(keep = True, reset_index = True)]
#
# TypeError: DataFrame.drop_duplicates() got an unexpected keyword argument 'reset_index'

# %%
df.[df.drp_duplicates()].reset_index()
# Out:
#   Cell In[12], line 1
#     df.[df.drp_duplicates()].reset_index()
#        ^
# SyntaxError: invalid syntax

# %%
df.[df.drp_duplicates().reset_index()]
# Out:
#   Cell In[13], line 1
#     df.[df.drp_duplicates().reset_index()]
#        ^
# SyntaxError: invalid syntax

# %%
rem_dup = df.drop_duplicates().reset_index()
print(rem_dup)
# Out:
#       index  CustomerId       Name  CreditScore  Country  Gender   Age  \
# 0         0  15634602.0   Hargrave          619   France  Female  42.0
# 1         2  15634602.0       Onio          502   France  Female  42.0
# 2         4  15737888.0   Mitchell          850    Spain  Female  43.0
# 3         5  15574012.0        Chu          645    Spain    Male  44.0
# 4         6  15574012.0   Bartlett          822   France    Male  50.0
# ...     ...         ...        ...          ...      ...     ...   ...
# 9984   9995  15606229.0   Obijiaku          771   France    Male  39.0
# 9985   9996  15569892.0  Johnstone          516   France    Male  35.0
# 9986   9998  15682355.0  Sabbatini          772  Germany    Male  42.0
# 9987   9999  15628319.0     Walker          792   France  Female  28.0
# 9988  10000         NaN        NaN      6505288      NaN     NaN   NaN
#
#       Tenure    Balance  NumOfProducts     Salary  Exited
# ...

# %%
rem_dup.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# Length: 9989, dtype: bool

# %%
rem_dup.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicates()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15608\2026555045.py in ?()
# ----> 1 df[df.duplicates()]
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
print(df[duplicates])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(df[duplicates])
#
# NameError: name 'duplicates' is not defined

# %%
duplicates = df.duplicated()
print(df[duplicates])
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 155   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 156   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 157   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 9991  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 9997  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
# ...

# %%
duplicates = df.duplicated().reset_index()
print(df[duplicates])
# Out:
#        CustomerId Name  CreditScore Country Gender  Age  Tenure  Balance  \
# 0             NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 1             NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 2             NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 3             NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 4             NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# ...           ...  ...          ...     ...    ...  ...     ...      ...
# 9996          NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 9997          NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 9998          NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 9999          NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
# 10000         NaN  NaN          NaN     NaN    NaN  NaN     NaN      NaN
#
#        NumOfProducts  Salary  Exited
# 0                NaN     NaN     NaN
# ...

# %%
duplicates = df.duplicated()
print(df[duplicates])
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 155   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 156   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 157   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 9991  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 9997  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
# ...

# %%
df[df.duplicated(subset = ['CustomerId'])]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0        Onio          502   France  Female  42.0     8.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 6     15574012.0    Bartlett          822   France    Male  50.0     7.0
# 7     15574012.0    Bartlett          376  Germany  Female  29.0     4.0
# 8     15574012.0    Bartlett          501   France    Male  44.0     4.0
# 9     15574012.0    Bartlett          684   France    Male  27.0     2.0
# 10    15574012.0    Bartlett          528   France    Male  31.0     6.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# ...

# %%
df[df.duplicated(subset = ['CustomerId'])].sum()
# Out:
# CustomerId                                             282325250.0
# Name             HargraveOnioOnioBartlettBartlettBartlettBartle...
# CreditScore                                                  11154
# Country          FranceFranceFranceFranceGermanyFranceFranceFra...
# Gender           FemaleFemaleFemaleMaleFemaleMaleMaleMaleMaleMa...
# Age                                                          665.0
# Tenure                                                       107.0
# Balance                                                  1237009.9
# NumOfProducts                                                 36.0
# Salary                                                  1984360.79
# Exited                                                         4.0
# dtype: object

# %%
df[df.duplicated(subset = ['CustomerId'])].count()
# Out:
# CustomerId       18
# Name             18
# CreditScore      18
# Country          18
# Gender           18
# Age              18
# Tenure           18
# Balance          18
# NumOfProducts    18
# Salary           18
# Exited           18
# dtype: int64

# %%
df['Name'] = df['Name'].where(df.duplicated(subset = ['Name']), 'duplicate')

# %%
df[df.duplicated(subset = ['Name'])]
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 2      15634602.0  duplicate          502   France  Female  42.0     8.0
# 4      15737888.0  duplicate          850    Spain  Female  43.0     2.0
# 5      15574012.0  duplicate          645    Spain    Male  44.0     8.0
# 6      15574012.0  duplicate          822   France    Male  50.0     7.0
# 8      15574012.0   Bartlett          501   France    Male  44.0     4.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0  duplicate          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0  duplicate          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0  duplicate          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df[df.duplicated(subset = ['CustomerId'])]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 2     15634602.0   duplicate          502   France  Female  42.0     8.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 6     15574012.0   duplicate          822   France    Male  50.0     7.0
# 7     15574012.0    Bartlett          376  Germany  Female  29.0     4.0
# 8     15574012.0    Bartlett          501   France    Male  44.0     4.0
# 9     15574012.0    Bartlett          684   France    Male  27.0     2.0
# 10    15574012.0    Bartlett          528   France    Male  31.0     6.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# ...

# %%
df[df.duplicated(subset = ['CustomerId']).count()
# Out:
#   Cell In[29], line 1
#     df[df.duplicated(subset = ['CustomerId']).count()
#                                                      ^
# _IncompleteInputError: incomplete input

# %%
df[df.duplicated(subset = ['CustomerId'])].count()
# Out:
# CustomerId       18
# Name             18
# CreditScore      18
# Country          18
# Gender           18
# Age              18
# Tenure           18
# Balance          18
# NumOfProducts    18
# Salary           18
# Exited           18
# dtype: int64

# %%
df['CustomerId'] = df['CustomerId'].where(df.duplicated(subset = ['CustomerId']), 'duplicated')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      CustomerId      Name  CreditScore Country Gender   Age  Tenure  \
# 13   15737173.0   Andrews          528   Spain   Male  24.0     3.0
# 154  15811589.0  Metcalfe          716   Spain   Male  42.0     8.0
# 155  15811589.0  Metcalfe          716   Spain   Male  42.0     8.0
# 156  15811589.0  Metcalfe          716   Spain   Male  42.0     8.0
# 157  15811589.0  Metcalfe          716   Spain   Male  42.0     8.0
#
#        Balance  NumOfProducts     Salary  Exited
# 13   142051.07            2.0   76390.01     0.0
# 154       0.00            2.0  180800.42     0.0
# 155       0.00            2.0  180800.42     0.0
# 156       0.00            2.0  180800.42     0.0
# 157       0.00            2.0  180800.42     0.0

# %%
df['CustomerId'] = df['CustomerId'].where(df.duplicated(subset = ['CustomerId']), 'duplicated')
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated  duplicate          619   France  Female  42.0     2.0
# 1      duplicated   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0  duplicate          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      duplicated  duplicate          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df['CustomerId'] = df['CustomerId'].where(df.duplicated(subset = ['CustomerId']), 'duplicated')
df[df.duplicated(subset = ['CustomerId'])]
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 1      duplicated   Hargrave          619   France  Female  42.0     2.0
# 2      duplicated  duplicate          502   France  Female  42.0     8.0
# 4      duplicated  duplicate          850    Spain  Female  43.0     2.0
# 5      duplicated  duplicate          645    Spain    Male  44.0     8.0
# 6      duplicated  duplicate          822   France    Male  50.0     7.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df[df.duplicated()]
# Out:
#       CustomerId        Name  CreditScore  Country Gender   Age  Tenure  \
# 13    duplicated     Andrews          528    Spain   Male  24.0     3.0
# 154   duplicated    Metcalfe          716    Spain   Male  42.0     8.0
# 156   15811589.0    Metcalfe          716    Spain   Male  42.0     8.0
# 157   15811589.0    Metcalfe          716    Spain   Male  42.0     8.0
# 9991  duplicated  Nkemakonam          714  Germany   Male  33.0     3.0
# 9997  duplicated   Johnstone          516   France   Male  35.0    10.0
#
#         Balance  NumOfProducts     Salary  Exited
# 13    142051.07            2.0   76390.01     0.0
# 154        0.00            2.0  180800.42     0.0
# 156        0.00            2.0  180800.42     0.0
# 157        0.00            2.0  180800.42     0.0
# 9991   35016.60            1.0   53667.08     0.0
# 9997   57369.61            1.0  101699.77     0.0

# %%
print(df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9996     False
# 9997      True
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
print(df[df])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15608\3086532637.py in ?()
# ----> 1 print(df[df])
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10980                         stacklevel=2,
#   10981                     )
#   10982
#   10983         other = common.apply_if_callable(other, self)
# ...

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated  duplicate          619   France  Female  42.0     2.0
# 1      duplicated   Hargrave          619   France  Female  42.0     2.0
# 2      duplicated  duplicate          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      duplicated  duplicate          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df[df['Age'] < 30]
# Out:
#       CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 7     duplicated   Bartlett          376  Germany  Female  29.0     4.0
# 9     15574012.0   Bartlett          684   France    Male  27.0     2.0
# 11    duplicated  duplicate          528    Spain    Male  24.0     3.0
# 12    duplicated    Andrews          528    Spain    Male  24.0     3.0
# 13    duplicated    Andrews          528    Spain    Male  24.0     3.0
# ...          ...        ...          ...      ...     ...   ...     ...
# 9973  duplicated     Miller          611   France    Male  27.0     7.0
# 9989  duplicated   McMillan          841    Spain    Male  28.0     4.0
# 9993  duplicated     Rahman          644   France    Male  28.0     7.0
# 9994  duplicated       Wood          800   France  Female  29.0     2.0
# 9999  duplicated     Walker          792   France  Female  28.0     4.0
#
#         Balance  NumOfProducts     Salary  Exited
# 7     115046.74            4.0  119346.88     1.0
# ...

# %%
df[df['Age']<20]
# Out:
#       CustomerId             Name  CreditScore  Country  Gender   Age  Tenure  \
# 57    duplicated        duplicate          725  Germany    Male  19.0     0.0
# 746   duplicated            Hsieh          844   France    Male  18.0     2.0
# 923   duplicated        Gallagher          572  Germany  Female  19.0     1.0
# 1619  duplicated         McDonald          656   France    Male  18.0    10.0
# 1678  duplicated        duplicate          570   France  Female  18.0     4.0
# 2021  duplicated        duplicate          716  Germany  Female  18.0     3.0
# 2136  duplicated         Bellucci          727   France    Male  18.0     4.0
# 2141  duplicated          Wallace          674   France    Male  18.0     7.0
# 2311  duplicated         McGregor          645   France    Male  19.0     9.0
# 2669  duplicated        duplicate          614   France  Female  19.0     5.0
# 2990  duplicated         Thurgood          491  Germany    Male  19.0     2.0
# ...

# %%
df[df['Age'].min()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: np.float64(18.0)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df[df['Age'].min()]
#
# ...

# %%
df['Age'].min()
# Out:
# np.float64(18.0)

# %%
df[df['Age']<19]
# Out:
#       CustomerId             Name  CreditScore  Country  Gender   Age  Tenure  \
# 746   duplicated            Hsieh          844   France    Male  18.0     2.0
# 1619  duplicated         McDonald          656   France    Male  18.0    10.0
# 1678  duplicated        duplicate          570   France  Female  18.0     4.0
# 2021  duplicated        duplicate          716  Germany  Female  18.0     3.0
# 2136  duplicated         Bellucci          727   France    Male  18.0     4.0
# 2141  duplicated          Wallace          674   France    Male  18.0     7.0
# 3330  duplicated             Chao          738   France    Male  18.0     4.0
# 3512  duplicated        duplicate          806    Spain    Male  18.0     3.0
# 3517  duplicated          Burgess          771    Spain    Male  18.0     1.0
# 3686  duplicated         Cattaneo          706   France    Male  18.0     2.0
# 4556  duplicated          Nwankwo          681   France  Female  18.0     1.0
# ...

# %%
df[df(subset = ['Gender']) & df['Gender'] == 'Female']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df[df(subset = ['Gender']) & df['Gender'] == 'Female']
#
# TypeError: 'DataFrame' object is not callable

# %%
female = df[df(subset = ['Gender'])]
print(female)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 female = df[df(subset = ['Gender'])]
#       2 print(female)
#
# TypeError: 'DataFrame' object is not callable

# %%
female = df[df['Gender'] == 'Female']
print(female)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0     duplicated  duplicate          619   France  Female  42.0     2.0
# 1     duplicated   Hargrave          619   France  Female  42.0     2.0
# 2     duplicated  duplicate          502   France  Female  42.0     8.0
# 3     15634602.0       Onio          502   France  Female  42.0     8.0
# 4     duplicated  duplicate          850    Spain  Female  43.0     2.0
# ...          ...        ...          ...      ...     ...   ...     ...
# 9977  duplicated    Mancini          683   France  Female  32.0     9.0
# 9979  duplicated     Diribe          677   France  Female  58.0     1.0
# 9982  duplicated    Griffin          655  Germany  Female  46.0     7.0
# 9994  duplicated       Wood          800   France  Female  29.0     2.0
# 9999  duplicated     Walker          792   France  Female  28.0     4.0
#
#         Balance  NumOfProducts     Salary  Exited
# 0          0.00            1.0  101348.88     1.0
# ...

# %%
female['Age']<20
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9977    False
# 9979    False
# 9982    False
# 9994    False
# 9999    False
# Name: Age, Length: 4536, dtype: bool

# %%
female[female['Age'] < 20]
# Out:
#       CustomerId         Name  CreditScore  Country  Gender   Age  Tenure  \
# 923   duplicated    Gallagher          572  Germany  Female  19.0     1.0
# 1678  duplicated    duplicate          570   France  Female  18.0     4.0
# 2021  duplicated    duplicate          716  Germany  Female  18.0     3.0
# 2669  duplicated    duplicate          614   France  Female  19.0     5.0
# 3239  duplicated          Hao          762    Spain  Female  19.0     6.0
# 3295  duplicated    duplicate          754    Spain  Female  19.0     9.0
# 4218  duplicated           Ku          589  Germany  Female  19.0     9.0
# 4330  duplicated    Anayolisa          781   France  Female  19.0     3.0
# 4556  duplicated      Nwankwo          681   France  Female  18.0     1.0
# 4727  duplicated       Barese          648   France  Female  19.0     1.0
# 6319  duplicated      Beavers          642  Germany  Female  19.0     3.0
# 8786  duplicated    duplicate          741  Germany  Female  19.0     8.0
# ...

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated  duplicate          619   France  Female  42.0     2.0
# 1      duplicated   Hargrave          619   France  Female  42.0     2.0
# 2      duplicated  duplicate          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      duplicated  duplicate          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated  duplicate      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
filter_name = df[df.drop_duplicates(subset = ['Name'], keep = 'first') & df['Age'] == 42]
print(filter_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 filter_name = df[df.drop_duplicates(subset = ['Name'], keep = 'first') & df['Age'] == 42]
#       2 print(filter_name)
#
# ...

# %%
filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
print(filter)
# Out:
#   Cell In[52], line 1
#     filter = df[(df.drop_duplicates(subset = ['Name', keep = 'first']) & (df['Age'] == 42))]
#                                                       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#df_filtered = df[~(df.duplicated(subset=['Name']) & (df['Age'] == 30))]

filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
print(filter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 #df_filtered = df[~(df.duplicated(subset=['Name']) & (df['Age'] == 30))]
# ...

# %%
filter = df[(df.drop_duplicated(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
print(filter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15608\3561795365.py in ?()
# ----> 1 filter = df[(df.drop_duplicated(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
#       2 print(filter)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_duplicated'

# %%
filter = df[(df.duplicated(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
print(filter)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 2     duplicated  duplicate          502   France  Female  42.0     8.0
# 33    duplicated  duplicate          520    Spain  Female  42.0     6.0
# 54    duplicated  duplicate          601  Germany    Male  42.0     1.0
# 112   duplicated  duplicate          562   France    Male  42.0     2.0
# 125   duplicated  duplicate          432   France    Male  42.0     9.0
# ...          ...        ...          ...      ...     ...   ...     ...
# 9880  duplicated     Thorpe          584  Germany    Male  42.0     3.0
# 9937  duplicated  duplicate          700   France  Female  42.0     8.0
# 9970  duplicated   Thompson          518   France    Male  42.0     7.0
# 9981  duplicated  duplicate          498  Germany    Male  42.0     3.0
# 9998  duplicated  Sabbatini          772  Germany    Male  42.0     3.0
#
#         Balance  NumOfProducts     Salary  Exited
# 2     159660.80            3.0  112542.58     1.0
# ...

# %%
filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
print(filter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') & (df['Age'] == 42))]
#       2 print(filter)
#
# ...

# %%
filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') and (df['Age'] == 42))]
print(filter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15608\1953604501.py in ?()
# ----> 1 filter = df[(df.drop_duplicates(subset = ['Name'], keep = 'first') and (df['Age'] == 42))]
#       2 print(filter)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df.drop_duplicates(subset = ['Name'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15608\2049089274.py in ?()
# ----> 1 df[df.drop_duplicates(subset = ['Name'])]
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10980                         stacklevel=2,
#   10981                     )
#   10982
#   10983         other = common.apply_if_callable(other, self)
# ...

# %%
import pandas as pd
file_path = "C:\\Users\\Sivaraman\\Desktop\\study\\data analytics\\Data (for practice)\\bank_details_1.csv"
df = pd.read_csv(file_path)
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df[df.duplicated()]
# Out:
#       CustomerId        Name  CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0    Hargrave          619   France  Female  42.0     2.0
# 3     15634602.0        Onio          502   France  Female  42.0     8.0
# 12    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 13    15737173.0     Andrews          528    Spain    Male  24.0     3.0
# 151   15650237.0      Morgan          754    Spain  Female  32.0     7.0
# 153   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 154   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 155   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 156   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 157   15811589.0    Metcalfe          716    Spain    Male  42.0     8.0
# 9991  15798964.0  Nkemakonam          714  Germany    Male  33.0     3.0
# 9997  15569892.0   Johnstone          516   France    Male  35.0    10.0
#
# ...

# %%
df['CustomerId'] = df[df.duplicated(subset = ['CustomerId']).df['CustomerId'] = 'duplicate']
# Out:
#   Cell In[3], line 1
#     df['CustomerId'] = df[df.duplicated(subset = ['CustomerId']).df['CustomerId'] = 'duplicate']
#                           ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %%
#df['CustomerId'] = df['CustomerId'].where(df.duplicated(subset = ['CustomerId']), 'duplicated')
#df[df.duplicated(subset = ['CustomerId'])]

df['CustomerId'] = df['CustomerId'].where(df.duplicated(subset = 'CustomerId'), 'duplicated')

# %%
df[df.duplicated(subset = ['CustomerId'])]
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      duplicated   Mitchell          850    Spain  Female  43.0     2.0
# 5      duplicated        Chu          645    Spain    Male  44.0     8.0
# 7      15574012.0   Bartlett          376  Germany  Female  29.0     4.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9995   duplicated   Obijiaku          771   France    Male  39.0     5.0
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df['Country'] = df['Country'].where(df(subset = ['Country']) == 'Spain')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df['Country'] = df['Country'].where(df(subset = ['Country']) == 'Spain')
#
# TypeError: 'DataFrame' object is not callable

# %%
df['Country'] = df['country'].replace('Spain', 'USA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ...

# %%
df['Country'] = df['Country'].replace('Spain', 'USA')
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.loc[3, 'Country'] = 'India'

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502    India  Female  42.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.loc(3, 'Name') = 'Siva'
print(df)
# Out:
#   Cell In[11], line 1
#     df.loc(3, 'Name') = 'Siva'
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
df.loc[3, 'Name'] = 'Siva'
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Siva          502    India  Female  42.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.loc[3, 'Gender'] = 'Male'
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Siva          502    India    Male  42.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.loc[3, 'Age'] = 23
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Siva          502    India    Male  23.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
df.loc[3,'CreaditScore'] = 850
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Siva          502    India    Male  23.0     8.0
# 4      duplicated   Mitchell          850      USA  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker          792   France  Female  28.0     4.0
# 10000  duplicated        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df.loc[3, 'CreditScore'] = '849'
print(df)
# Out:
#        CustomerId       Name CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave         619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave         619   France  Female  42.0     2.0
# 2      15634602.0       Onio         502   France  Female  42.0     8.0
# 3      15634602.0       Siva         849    India    Male  23.0     8.0
# 4      duplicated   Mitchell         850      USA  Female  43.0     2.0
# ...           ...        ...         ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone         516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone         516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini         772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker         792   France  Female  28.0     4.0
# 10000  duplicated        NaN     6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df_filtered = df[df.drop_duplicates(subset = ['Name']) & (df['Age'] == 42)
print(df_filtered)
# Out:
#   Cell In[17], line 1
#     df_filtered = df[df.drop_duplicates(subset = ['Name']) & (df['Age'] == 42)
#                     ^
# SyntaxError: '[' was never closed

# %%
df_filtered = df[df.drop_duplicates(subset = ['Name']) & (df['Age'] == 42)]
print(df_filtered)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_filtered = df[df.drop_duplicates(subset = ['Name']) & (df['Age'] == 42)]
#       2 print(df_filtered)
#
# ...

# %%
df_filtered = df[df.drop_duplicates(subset = ['Name']) & (df['Age'] == 42)]
print(df_filtered)

# %%
#df_filtered = df[~(df.duplicated(subset=['ID']) & (df['Name'] == 'Bob'))]
df_filtered = df[(df.duplicated(subset = ['Name']) & (df['Age'] == 42))]
print(df_filtered)
# Out:
#       CustomerId       Name CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0   Hargrave         619   France  Female  42.0     2.0
# 94    duplicated      Capon         730      USA    Male  42.0     4.0
# 153   15811589.0   Metcalfe         716      USA    Male  42.0     8.0
# 154   15811589.0   Metcalfe         716      USA    Male  42.0     8.0
# 155   15811589.0   Metcalfe         716      USA    Male  42.0     8.0
# ...          ...        ...         ...      ...     ...   ...     ...
# 9774  duplicated       Tsui         679   France    Male  42.0     1.0
# 9793  duplicated     Hilton         772  Germany  Female  42.0     0.0
# 9880  duplicated     Thorpe         584  Germany    Male  42.0     3.0
# 9970  duplicated   Thompson         518   France    Male  42.0     7.0
# 9998  duplicated  Sabbatini         772  Germany    Male  42.0     3.0
#
#         Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df_filtered.drop_duplicates()
# Out:
#       CustomerId       Name CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0   Hargrave         619   France  Female  42.0     2.0
# 94    duplicated      Capon         730      USA    Male  42.0     4.0
# 153   15811589.0   Metcalfe         716      USA    Male  42.0     8.0
# 183   duplicated      T'ang         636   France    Male  42.0     2.0
# 283   duplicated     Ch'ien         807   France    Male  42.0     7.0
# ...          ...        ...         ...      ...     ...   ...     ...
# 9774  duplicated       Tsui         679   France    Male  42.0     1.0
# 9793  duplicated     Hilton         772  Germany  Female  42.0     0.0
# 9880  duplicated     Thorpe         584  Germany    Male  42.0     3.0
# 9970  duplicated   Thompson         518   France    Male  42.0     7.0
# 9998  duplicated  Sabbatini         772  Germany    Male  42.0     3.0
#
#         Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df_filtered = df[(df.duplicated(subset = ['Name']) & (df['Age'] < 25))]
print(df_filtered)
# Out:
#       CustomerId             Name CreditScore Country  Gender   Age  Tenure  \
# 12    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 13    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 508   duplicated        Okechukwu         733  France    Male  22.0     5.0
# 684   duplicated        Trevisani         583  France    Male  24.0     9.0
# 741   duplicated            Rossi         546  France    Male  24.0     8.0
# ...          ...              ...         ...     ...     ...   ...     ...
# 9866  duplicated            Allan         667  France    Male  24.0     4.0
# 9887  duplicated              Mao         684     USA    Male  24.0     8.0
# 9932  duplicated  Fleetwood-Smith         677     USA    Male  18.0     8.0
# 9940  duplicated      Bergamaschi         748  France  Female  20.0     7.0
# 9943  duplicated               Fu         784     USA    Male  23.0     2.0
#
# ...

# %%
df_filtered.drop_duplicates()
# Out:
#       CustomerId             Name CreditScore Country  Gender   Age  Tenure  \
# 12    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 508   duplicated        Okechukwu         733  France    Male  22.0     5.0
# 684   duplicated        Trevisani         583  France    Male  24.0     9.0
# 741   duplicated            Rossi         546  France    Male  24.0     8.0
# 746   duplicated            Hsieh         844  France    Male  18.0     2.0
# ...          ...              ...         ...     ...     ...   ...     ...
# 9866  duplicated            Allan         667  France    Male  24.0     4.0
# 9887  duplicated              Mao         684     USA    Male  24.0     8.0
# 9932  duplicated  Fleetwood-Smith         677     USA    Male  18.0     8.0
# 9940  duplicated      Bergamaschi         748  France  Female  20.0     7.0
# 9943  duplicated               Fu         784     USA    Male  23.0     2.0
#
# ...

# %%
df_creadit_score = df_filtered['CreditScore'] > 600
print(df_filtered[df_creadit_score])
# Out:
#       CustomerId             Name CreditScore  Country  Gender   Age  Tenure  \
# 508   duplicated        Okechukwu         733   France    Male  22.0     5.0
# 746   duplicated            Hsieh         844   France    Male  18.0     2.0
# 763   duplicated              Chu         742  Germany  Female  21.0     1.0
# 1013  duplicated          Nwankwo         635      USA    Male  24.0     4.0
# 1031  duplicated         Crawford         631   France  Female  22.0     3.0
# ...          ...              ...         ...      ...     ...   ...     ...
# 9866  duplicated            Allan         667   France    Male  24.0     4.0
# 9887  duplicated              Mao         684      USA    Male  24.0     8.0
# 9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0     8.0
# 9940  duplicated      Bergamaschi         748   France  Female  20.0     7.0
# 9943  duplicated               Fu         784      USA    Male  23.0     2.0
#
# ...

# %%
df_balance = df[(df.duplicated(subset = ['Name']) & (df['Salary'] > 100000))]
print(df_balance)
# Out:
#       CustomerId         Name CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0     Hargrave         619   France  Female  42.0     2.0
# 7     15574012.0     Bartlett         376  Germany  Female  29.0     4.0
# 89    duplicated      Osborne         635  Germany  Female  28.0     3.0
# 114   duplicated      Fanucci         721  Germany    Male  28.0     9.0
# 122   duplicated      Cameron         656   France  Female  39.0     6.0
# ...          ...          ...         ...      ...     ...   ...     ...
# 9989  duplicated     McMillan         841      USA    Male  28.0     4.0
# 9992  duplicated  Chukwualuka         726      USA    Male  36.0     2.0
# 9994  duplicated         Wood         800   France  Female  29.0     2.0
# 9996  duplicated    Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0    Johnstone         516   France    Male  35.0    10.0
#
#         Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df_balance['Name'] < df_balance['Age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_balance['Name'] < df_balance['Age']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...

# %%
df_balance['Age'] < 25
# Out:
# 1       False
# 7       False
# 89      False
# 114     False
# 122     False
#         ...
# 9989    False
# 9992    False
# 9994    False
# 9996    False
# 9997    False
# Name: Age, Length: 3555, dtype: bool

# %%
print(df_balance)
# Out:
#       CustomerId         Name CreditScore  Country  Gender   Age  Tenure  \
# 1     15634602.0     Hargrave         619   France  Female  42.0     2.0
# 7     15574012.0     Bartlett         376  Germany  Female  29.0     4.0
# 89    duplicated      Osborne         635  Germany  Female  28.0     3.0
# 114   duplicated      Fanucci         721  Germany    Male  28.0     9.0
# 122   duplicated      Cameron         656   France  Female  39.0     6.0
# ...          ...          ...         ...      ...     ...   ...     ...
# 9989  duplicated     McMillan         841      USA    Male  28.0     4.0
# 9992  duplicated  Chukwualuka         726      USA    Male  36.0     2.0
# 9994  duplicated         Wood         800   France  Female  29.0     2.0
# 9996  duplicated    Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0    Johnstone         516   France    Male  35.0    10.0
#
#         Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
 below_25 = df_balance['Age'] <  25
print(below_25)
# Out:
# 1       False
# 7       False
# 89      False
# 114     False
# 122     False
#         ...
# 9989    False
# 9992    False
# 9994    False
# 9996    False
# 9997    False
# Name: Age, Length: 3555, dtype: bool

# %%
df_balance[df_balance['Age'] <  25]
# Out:
#       CustomerId             Name CreditScore  Country  Gender   Age  Tenure  \
# 508   duplicated        Okechukwu         733   France    Male  22.0     5.0
# 741   duplicated            Rossi         546   France    Male  24.0     8.0
# 746   duplicated            Hsieh         844   France    Male  18.0     2.0
# 1064  duplicated            Smith         723   France  Female  20.0     4.0
# 1072  duplicated     Dumetochukwu         624      USA  Female  23.0     6.0
# ...          ...              ...         ...      ...     ...   ...     ...
# 9752  duplicated            Hsieh         690   France    Male  21.0     8.0
# 9794  duplicated         Thompson         685      USA    Male  23.0     5.0
# 9796  duplicated           Thorpe         642  Germany    Male  22.0    10.0
# 9866  duplicated            Allan         667   France    Male  24.0     4.0
# 9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0     8.0
#
# ...

# %%
print(df)
# Out:
#        CustomerId       Name CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave         619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave         619   France  Female  42.0     2.0
# 2      15634602.0       Onio         502   France  Female  42.0     8.0
# 3      15634602.0       Siva         849    India    Male  23.0     8.0
# 4      duplicated   Mitchell         850      USA  Female  43.0     2.0
# ...           ...        ...         ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone         516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone         516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini         772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker         792   France  Female  28.0     4.0
# 10000  duplicated        NaN     6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df_filtered = df[(df.duplicated(subset = ['Country']) & (df['Age'] == 35))]
print(df_filtered)
# Out:
#       CustomerId            Name CreditScore  Country  Gender   Age  Tenure  \
# 14    duplicated           Scott         528      USA  Female  35.0     7.0
# 60    duplicated          Hunter         742  Germany    Male  35.0     5.0
# 68    duplicated         Glauert         661  Germany  Female  35.0     5.0
# 95    duplicated      Fiorentini         515      USA    Male  35.0    10.0
# 109   duplicated           T'ang         479  Germany    Male  35.0     9.0
# ...          ...             ...         ...      ...     ...   ...     ...
# 9966  duplicated           Ch'en         479      USA    Male  35.0     4.0
# 9980  duplicated            T'ao         741      USA    Male  35.0     6.0
# 9984  duplicated  Echezonachukwu         602  Germany    Male  35.0     7.0
# 9996  duplicated       Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0       Johnstone         516   France    Male  35.0    10.0
#
# ...

# %%
df_filtered[df_filtered.drop_duplicates()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19196\2934160789.py in ?()
# ----> 1 df_filtered[df_filtered.drop_duplicates()]
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
#    4091         # Do we have a (boolean) 1d indexer?
#    4092         if com.is_bool_indexer(key):
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   10980                         stacklevel=2,
#   10981                     )
#   10982
#   10983         other = common.apply_if_callable(other, self)
# ...

# %%
df_filtered.drop_duplicates()
# Out:
#       CustomerId            Name CreditScore  Country  Gender   Age  Tenure  \
# 14    duplicated           Scott         528      USA  Female  35.0     7.0
# 60    duplicated          Hunter         742  Germany    Male  35.0     5.0
# 68    duplicated         Glauert         661  Germany  Female  35.0     5.0
# 95    duplicated      Fiorentini         515      USA    Male  35.0    10.0
# 109   duplicated           T'ang         479  Germany    Male  35.0     9.0
# ...          ...             ...         ...      ...     ...   ...     ...
# 9966  duplicated           Ch'en         479      USA    Male  35.0     4.0
# 9980  duplicated            T'ao         741      USA    Male  35.0     6.0
# 9984  duplicated  Echezonachukwu         602  Germany    Male  35.0     7.0
# 9996  duplicated       Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0       Johnstone         516   France    Male  35.0    10.0
#
# ...

# %%
print(df_filtered)
# Out:
#       CustomerId            Name CreditScore  Country  Gender   Age  Tenure  \
# 14    duplicated           Scott         528      USA  Female  35.0     7.0
# 60    duplicated          Hunter         742  Germany    Male  35.0     5.0
# 68    duplicated         Glauert         661  Germany  Female  35.0     5.0
# 95    duplicated      Fiorentini         515      USA    Male  35.0    10.0
# 109   duplicated           T'ang         479  Germany    Male  35.0     9.0
# ...          ...             ...         ...      ...     ...   ...     ...
# 9966  duplicated           Ch'en         479      USA    Male  35.0     4.0
# 9980  duplicated            T'ao         741      USA    Male  35.0     6.0
# 9984  duplicated  Echezonachukwu         602  Germany    Male  35.0     7.0
# 9996  duplicated       Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0       Johnstone         516   France    Male  35.0    10.0
#
# ...

# %%
df_filtered[].reset_index()
# Out:
#   Cell In[42], line 1
#     df_filtered[].reset_index()
#                 ^
# SyntaxError: invalid syntax

# %%
df_filtered.reset_index()
# Out:
#      index  CustomerId            Name CreditScore  Country  Gender   Age  \
# 0       14  duplicated           Scott         528      USA  Female  35.0
# 1       60  duplicated          Hunter         742  Germany    Male  35.0
# 2       68  duplicated         Glauert         661  Germany  Female  35.0
# 3       95  duplicated      Fiorentini         515      USA    Male  35.0
# 4      109  duplicated           T'ang         479  Germany    Male  35.0
# ..     ...         ...             ...         ...      ...     ...   ...
# 470   9966  duplicated           Ch'en         479      USA    Male  35.0
# 471   9980  duplicated            T'ao         741      USA    Male  35.0
# 472   9984  duplicated  Echezonachukwu         602  Germany    Male  35.0
# 473   9996  duplicated       Johnstone         516   France    Male  35.0
# 474   9997  15569892.0       Johnstone         516   France    Male  35.0
#
#      Tenure    Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
cleaned_data = df_filtered
print(cleaned_data)
# Out:
#       CustomerId            Name CreditScore  Country  Gender   Age  Tenure  \
# 14    duplicated           Scott         528      USA  Female  35.0     7.0
# 60    duplicated          Hunter         742  Germany    Male  35.0     5.0
# 68    duplicated         Glauert         661  Germany  Female  35.0     5.0
# 95    duplicated      Fiorentini         515      USA    Male  35.0    10.0
# 109   duplicated           T'ang         479  Germany    Male  35.0     9.0
# ...          ...             ...         ...      ...     ...   ...     ...
# 9966  duplicated           Ch'en         479      USA    Male  35.0     4.0
# 9980  duplicated            T'ao         741      USA    Male  35.0     6.0
# 9984  duplicated  Echezonachukwu         602  Germany    Male  35.0     7.0
# 9996  duplicated       Johnstone         516   France    Male  35.0    10.0
# 9997  15569892.0       Johnstone         516   France    Male  35.0    10.0
#
# ...

# %%
cleaned_data = df_filtered.reset_index()
print(cleaned_data)
# Out:
#      index  CustomerId            Name CreditScore  Country  Gender   Age  \
# 0       14  duplicated           Scott         528      USA  Female  35.0
# 1       60  duplicated          Hunter         742  Germany    Male  35.0
# 2       68  duplicated         Glauert         661  Germany  Female  35.0
# 3       95  duplicated      Fiorentini         515      USA    Male  35.0
# 4      109  duplicated           T'ang         479  Germany    Male  35.0
# ..     ...         ...             ...         ...      ...     ...   ...
# 470   9966  duplicated           Ch'en         479      USA    Male  35.0
# 471   9980  duplicated            T'ao         741      USA    Male  35.0
# 472   9984  duplicated  Echezonachukwu         602  Germany    Male  35.0
# 473   9996  duplicated       Johnstone         516   France    Male  35.0
# 474   9997  15569892.0       Johnstone         516   France    Male  35.0
#
#      Tenure    Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
cleaned_data.to_csv('cleaned_csv', keep = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 cleaned_data.to_csv('cleaned_csv', keep = False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'keep'

# %%
cleaned_data = df_filtered.reset_index()
cleaned_data.to_csv('cleaned_data.csv', index = False)
print(cleaned_data)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[53], line 2
#       1 cleaned_data = df_filtered.reset_index()
# ----> 2 cleaned_data.to_csv('cleaned_data.csv', index = True)
#       3 print(cleaned_data)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import os

file_path = 'cleaned_data.csv'

if os.path.exists(file_path):
    print("File exists:", file_path)
else:
    print("File not found!")
# Out:
# File exists: cleaned_data.csv

# %%
import os

file_path = 'cleaned_data.csv'

if os.path.exists(file_path):
    print('file is there')
else:print
    print('file is not there')
# Out:
# file is there

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cleaned_data.csv', 'data_practice_ja1.py', 'duplicate_handling.ipynb']

# %%
print(df)
# Out:
#        CustomerId       Name CreditScore  Country  Gender   Age  Tenure  \
# 0      duplicated   Hargrave         619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave         619   France  Female  42.0     2.0
# 2      15634602.0       Onio         502   France  Female  42.0     8.0
# 3      15634602.0       Siva         849    India    Male  23.0     8.0
# 4      duplicated   Mitchell         850      USA  Female  43.0     2.0
# ...           ...        ...         ...      ...     ...   ...     ...
# 9996   duplicated  Johnstone         516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone         516   France    Male  35.0    10.0
# 9998   duplicated  Sabbatini         772  Germany    Male  42.0     3.0
# 9999   duplicated     Walker         792   France  Female  28.0     4.0
# 10000  duplicated        NaN     6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited  CreaditScore
# ...

# %%
df['Age'] < 25
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Name: Age, Length: 10001, dtype: bool

# %%
df[df['Age'] < 25]
# Out:
#       CustomerId             Name CreditScore Country  Gender   Age  Tenure  \
# 3     15634602.0             Siva         849   India    Male  23.0     8.0
# 11    duplicated          Andrews         528     USA    Male  24.0     3.0
# 12    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 13    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 17    duplicated        Henderson         549     USA  Female  24.0     9.0
# ...          ...              ...         ...     ...     ...   ...     ...
# 9887  duplicated              Mao         684     USA    Male  24.0     8.0
# 9888  duplicated          Sturdee         637  France  Female  21.0    10.0
# 9932  duplicated  Fleetwood-Smith         677     USA    Male  18.0     8.0
# 9940  duplicated      Bergamaschi         748  France  Female  20.0     7.0
# 9943  duplicated               Fu         784     USA    Male  23.0     2.0
#
# ...

# %%
age_25 =df[ df['Age'] < 25]
print(age_25)
# Out:
#       CustomerId             Name CreditScore Country  Gender   Age  Tenure  \
# 3     15634602.0             Siva         849   India    Male  23.0     8.0
# 11    duplicated          Andrews         528     USA    Male  24.0     3.0
# 12    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 13    15737173.0          Andrews         528     USA    Male  24.0     3.0
# 17    duplicated        Henderson         549     USA  Female  24.0     9.0
# ...          ...              ...         ...     ...     ...   ...     ...
# 9887  duplicated              Mao         684     USA    Male  24.0     8.0
# 9888  duplicated          Sturdee         637  France  Female  21.0    10.0
# 9932  duplicated  Fleetwood-Smith         677     USA    Male  18.0     8.0
# 9940  duplicated      Bergamaschi         748  France  Female  20.0     7.0
# 9943  duplicated               Fu         784     USA    Male  23.0     2.0
#
# ...

# %%
sal_1L = age_25[age_25['Salary']> 100000]
print(sal_1L)
# Out:
#       CustomerId             Name CreditScore  Country  Gender   Age  Tenure  \
# 3     15634602.0             Siva         849    India    Male  23.0     8.0
# 86    duplicated             Gant         750      USA    Male  22.0     3.0
# 129   duplicated           Fernie         770   France    Male  24.0     9.0
# 166   duplicated          Taubman         704  Germany  Female  24.0     7.0
# 233   duplicated            Fiore         767  Germany    Male  20.0     3.0
# ...          ...              ...         ...      ...     ...   ...     ...
# 9794  duplicated         Thompson         685      USA    Male  23.0     5.0
# 9796  duplicated           Thorpe         642  Germany    Male  22.0    10.0
# 9866  duplicated            Allan         667   France    Male  24.0     4.0
# 9888  duplicated          Sturdee         637   France  Female  21.0    10.0
# 9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0     8.0
#
# ...

# %%
sal_1L.reset_index()
# Out:
#      index  CustomerId             Name CreditScore  Country  Gender   Age  \
# 0        3  15634602.0             Siva         849    India    Male  23.0
# 1       86  duplicated             Gant         750      USA    Male  22.0
# 2      129  duplicated           Fernie         770   France    Male  24.0
# 3      166  duplicated          Taubman         704  Germany  Female  24.0
# 4      233  duplicated            Fiore         767  Germany    Male  20.0
# ..     ...         ...              ...         ...      ...     ...   ...
# 240   9794  duplicated         Thompson         685      USA    Male  23.0
# 241   9796  duplicated           Thorpe         642  Germany    Male  22.0
# 242   9866  duplicated            Allan         667   France    Male  24.0
# 243   9888  duplicated          Sturdee         637   France  Female  21.0
# 244   9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0
#
# ...

# %%
print(sal_1L)
# Out:
#       CustomerId             Name CreditScore  Country  Gender   Age  Tenure  \
# 3     15634602.0             Siva         849    India    Male  23.0     8.0
# 86    duplicated             Gant         750      USA    Male  22.0     3.0
# 129   duplicated           Fernie         770   France    Male  24.0     9.0
# 166   duplicated          Taubman         704  Germany  Female  24.0     7.0
# 233   duplicated            Fiore         767  Germany    Male  20.0     3.0
# ...          ...              ...         ...      ...     ...   ...     ...
# 9794  duplicated         Thompson         685      USA    Male  23.0     5.0
# 9796  duplicated           Thorpe         642  Germany    Male  22.0    10.0
# 9866  duplicated            Allan         667   France    Male  24.0     4.0
# 9888  duplicated          Sturdee         637   France  Female  21.0    10.0
# 9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0     8.0
#
# ...

# %%
rst_index = sal_1L.reset_index()
print(rst_index)
# Out:
#      index  CustomerId             Name CreditScore  Country  Gender   Age  \
# 0        3  15634602.0             Siva         849    India    Male  23.0
# 1       86  duplicated             Gant         750      USA    Male  22.0
# 2      129  duplicated           Fernie         770   France    Male  24.0
# 3      166  duplicated          Taubman         704  Germany  Female  24.0
# 4      233  duplicated            Fiore         767  Germany    Male  20.0
# ..     ...         ...              ...         ...      ...     ...   ...
# 240   9794  duplicated         Thompson         685      USA    Male  23.0
# 241   9796  duplicated           Thorpe         642  Germany    Male  22.0
# 242   9866  duplicated            Allan         667   France    Male  24.0
# 243   9888  duplicated          Sturdee         637   France  Female  21.0
# 244   9932  duplicated  Fleetwood-Smith         677      USA    Male  18.0
#
# ...

# %%
'''cleaned_data = df_filtered.reset_index()
cleaned_data.to_csv('cleaned_data.csv', index = False)
print(cleaned_data)'''

rst_index.to_csv('filterd_data.csv')

df.to_csv('filterd_data.csv')

# %%
'''# Example row to check
row_to_check = {'ID': 101, 'Name': 'Alice'}

# Check if the row exists more than once
is_duplicated = (df == pd.Series(row_to_check)).all(axis=1).sum() > 1

print("Is the row duplicated?", is_duplicated)'''

import pandas as pd
file_path = "C:\\Users\\Sivaraman\\Desktop\\study\\data analytics\\Data (for practice)\\bank_details_1.csv"
df = pd.read_csv(file_path)
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender   Age  Tenure  \
# 0      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 1      15634602.0   Hargrave          619   France  Female  42.0     2.0
# 2      15634602.0       Onio          502   France  Female  42.0     8.0
# 3      15634602.0       Onio          502   France  Female  42.0     8.0
# 4      15737888.0   Mitchell          850    Spain  Female  43.0     2.0
# ...           ...        ...          ...      ...     ...   ...     ...
# 9996   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9997   15569892.0  Johnstone          516   France    Male  35.0    10.0
# 9998   15682355.0  Sabbatini          772  Germany    Male  42.0     3.0
# 9999   15628319.0     Walker          792   France  Female  28.0     4.0
# 10000         NaN        NaN      6505288      NaN     NaN   NaN     NaN
#
#          Balance  NumOfProducts     Salary  Exited
# ...

# %%
'''# Example row to check
row_to_check = {'ID': 101, 'Name': 'Alice'}

# Check if the row exists more than once
is_duplicated = (df == pd.Series(row_to_check)).all(axis=1).sum() > 1
#df.eq(pd.Series(row_to_check)).all(axis=1).sum() > 1

print("Is the row duplicated?", is_duplicated)'''

row_to_check = {'CustomerId':15628319, 'Name':'Walker'}
is_duplicated = df.eq(pd.series(row_to_check)).all(axis=1).sum()>1
print(is_duplicated)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 11
#       1 '''# Example row to check
#       2 row_to_check = {'ID': 101, 'Name': 'Alice'}
#       3
#    (...)
#       7
#       8 print("Is the row duplicated?", is_duplicated)'''
#      10 row_to_check = {'CustomerId':15628319, 'Name':'Walker'}
# ---> 11 is_duplicated = df.eq(pd.series(row_to_check)).all(axis=1).sum()>1
#      12 print(is_duplicated)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
df.coulumns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11076\414447740.py in ?()
# ----> 1 df.coulumns()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coulumns'

# %%
df.columns
# Out:
# Index(['CustomerId', 'Name', 'CreditScore', 'Country', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'Salary', 'Exited'],
#       dtype='object')

# %%
row_to_check = {'CustomerId':15628319, 'Name':'Walker'}
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum()>1
print(is_duplicated)
# Out:
# False

# %%
df
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerId     10000 non-null  float64
#  1   Name           10000 non-null  object
#  2   CreditScore    10001 non-null  int64
#  3   Country        10000 non-null  object
#  4   Gender         10000 non-null  object
#  5   Age            10000 non-null  float64
#  6   Tenure         10000 non-null  float64
#  7   Balance        10000 non-null  float64
#  8   NumOfProducts  10000 non-null  float64
#  9   Salary         10000 non-null  float64
#  10  Exited         10000 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 859.6+ KB

# %%
df.dtypes
# Out:
# CustomerId       float64
# Name              object
# CreditScore        int64
# Country           object
# Gender            object
# Age              float64
# Tenure           float64
# Balance          float64
# NumOfProducts    float64
# Salary           float64
# Exited           float64
# dtype: object

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
'''# Convert CustomerId to int, Age & Tenure to int
df['CustomerId'] = df['CustomerId'].astype(int)
df['Age'] = df['Age'].astype(int)
df['Tenure'] = df['Tenure'].astype(int)

# Strip spaces from Name column
df['Name'] = df['Name'].str.strip()

# Now define row_to_check with correct types
row_to_check = {'CustomerId': 15634602, 'Name': 'Hargrave'}

# Check for duplicates
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum() > 1

print("Is the row duplicated?", is_duplicated)
'''
df['CustomerId'] = df['CustomerId'].fillna(0).astype(int)
df['Age'] = df['Age'].fillna(0).astype(int)
df['Tenure'] = df['Tenure'].fillna(0).astype(int)

df['Name'] = df['Name'].str.strip()

row_to_check = {'CustomerId':15634602, 'Name':'Hargrave'}
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum()>1
print('Is_row_is_duplicated: ', is_duplicated)
# Out:
# Is_row_is_duplicated:  False

# %%
df['CustomerId'] = df['CustomerId'].fillna(0).astype(int)
df['Age'] = df['Age'].fillna(0).astype(int)
df['Tenure'] = df['Tenure'].fillna(0).astype(int)

df['Name'] = df['Name'].str.strip()

row_to_check = {'CustomerId':15634602, 'Name':'Hargrave'}
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum()>1
print('Is_row_is_duplicated: ', is_duplicated)
# Out:
# Is_row_is_duplicated:  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerId     10001 non-null  int64
#  1   Name           10000 non-null  object
#  2   CreditScore    10001 non-null  int64
#  3   Country        10000 non-null  object
#  4   Gender         10000 non-null  object
#  5   Age            10001 non-null  int64
#  6   Tenure         10001 non-null  int64
#  7   Balance        10000 non-null  float64
#  8   NumOfProducts  10000 non-null  float64
#  9   Salary         10000 non-null  float64
#  10  Exited         10000 non-null  float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 859.6+ KB

# %%
df.dtypes
# Out:
# CustomerId         int64
# Name              object
# CreditScore        int64
# Country           object
# Gender            object
# Age                int64
# Tenure             int64
# Balance          float64
# NumOfProducts    float64
# Salary           float64
# Exited           float64
# dtype: object

# %%
print(df['Name'].unique())
# Out:
# ['Hargrave' 'Onio' 'Mitchell' ... 'Aldridge' 'Burbidge' nan]

# %%
df['Name'].str.strip()
# Out:
# 0         Hargrave
# 1         Hargrave
# 2             Onio
# 3             Onio
# 4         Mitchell
#            ...
# 9996     Johnstone
# 9997     Johnstone
# 9998     Sabbatini
# 9999        Walker
# 10000          NaN
# Name: Name, Length: 10001, dtype: object

# %%
df['Name'] = df['Name'].str.strip()

# %%
df[df['Name'] != df['Name'].str.strip()]
# Out:
#        CustomerId Name  CreditScore Country Gender  Age  Tenure  Balance  \
# 10000           0  NaN      6505288     NaN    NaN    0       0      NaN
#
#        NumOfProducts  Salary  Exited
# 10000            NaN     NaN     NaN

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender  Age  Tenure  \
# 0        15634602   Hargrave          619   France  Female   42       2
# 1        15634602   Hargrave          619   France  Female   42       2
# 2        15634602       Onio          502   France  Female   42       8
# 3        15634602       Onio          502   France  Female   42       8
# 4        15737888   Mitchell          850    Spain  Female   43       2
# ...           ...        ...          ...      ...     ...  ...     ...
# 9996     15569892  Johnstone          516   France    Male   35      10
# 9997     15569892  Johnstone          516   France    Male   35      10
# 9998     15682355  Sabbatini          772  Germany    Male   42       3
# 9999     15628319     Walker          792   France  Female   28       4
# 10000           0        NaN      6505288      NaN     NaN    0       0
#
#          Balance  NumOfProducts     Salary  Exited
# 0           0.00            1.0  101348.88     1.0
# ...

# %%
df = df.fillna(0)

# %%
print(0)
# Out:
# 0

# %%
print(df)
# Out:
#        CustomerId       Name  CreditScore  Country  Gender  Age  Tenure  \
# 0        15634602   Hargrave          619   France  Female   42       2
# 1        15634602   Hargrave          619   France  Female   42       2
# 2        15634602       Onio          502   France  Female   42       8
# 3        15634602       Onio          502   France  Female   42       8
# 4        15737888   Mitchell          850    Spain  Female   43       2
# ...           ...        ...          ...      ...     ...  ...     ...
# 9996     15569892  Johnstone          516   France    Male   35      10
# 9997     15569892  Johnstone          516   France    Male   35      10
# 9998     15682355  Sabbatini          772  Germany    Male   42       3
# 9999     15628319     Walker          792   France  Female   28       4
# 10000           0          0      6505288        0       0    0       0
#
#          Balance  NumOfProducts     Salary  Exited
# 0           0.00            1.0  101348.88     1.0
# ...

# %%
df[df['Name'] != df['Name'].str.strip()]
# Out:
#        CustomerId Name  CreditScore Country Gender  Age  Tenure  Balance  \
# 10000           0    0      6505288       0      0    0       0      0.0
#
#        NumOfProducts  Salary  Exited
# 10000            0.0     0.0     0.0

# %%
print(df.shape)
# Out:
# (10001, 11)

# %%
df.drop(10001)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.drop(10001)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df = df.drop(index = 10000)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df = df.drop(index = 10000)
#       2 print(df)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df = df.drop(index=10000)  # Deletes the row with index 10000

# %%
print(df)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619   France  Female   42       2
# 1       15634602   Hargrave          619   France  Female   42       2
# 2       15634602       Onio          502   France  Female   42       8
# 3       15634602       Onio          502   France  Female   42       8
# 4       15737888   Mitchell          850    Spain  Female   43       2
# ...          ...        ...          ...      ...     ...  ...     ...
# 9995    15606229   Obijiaku          771   France    Male   39       5
# 9996    15569892  Johnstone          516   France    Male   35      10
# 9997    15569892  Johnstone          516   France    Male   35      10
# 9998    15682355  Sabbatini          772  Germany    Male   42       3
# 9999    15628319     Walker          792   France  Female   28       4
#
#         Balance  NumOfProducts     Salary  Exited
# 0          0.00            1.0  101348.88     1.0
# ...

# %%
df = df.drop(index = 10000)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = df.drop(index = 10000)
#       2 print(df)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df = df.drop(index = 9999)
print(df)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619   France  Female   42       2
# 1       15634602   Hargrave          619   France  Female   42       2
# 2       15634602       Onio          502   France  Female   42       8
# 3       15634602       Onio          502   France  Female   42       8
# 4       15737888   Mitchell          850    Spain  Female   43       2
# ...          ...        ...          ...      ...     ...  ...     ...
# 9994    15719294       Wood          800   France  Female   29       2
# 9995    15606229   Obijiaku          771   France    Male   39       5
# 9996    15569892  Johnstone          516   France    Male   35      10
# 9997    15569892  Johnstone          516   France    Male   35      10
# 9998    15682355  Sabbatini          772  Germany    Male   42       3
#
#         Balance  NumOfProducts     Salary  Exited
# 0          0.00            1.0  101348.88     1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerId     9999 non-null   int64
#  1   Name           9999 non-null   object
#  2   CreditScore    9999 non-null   int64
#  3   Country        9999 non-null   object
#  4   Gender         9999 non-null   object
#  5   Age            9999 non-null   int64
#  6   Tenure         9999 non-null   int64
#  7   Balance        9999 non-null   float64
#  8   NumOfProducts  9999 non-null   float64
#  9   Salary         9999 non-null   float64
#  10  Exited         9999 non-null   float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 859.4+ KB

# %%
df['NumOfProducts'] = df['NumOfProducts'].astype(int)
df['Exited'] = df['Exited'].astype(int)
print(df.dtypes)
# Out:
# CustomerId         int64
# Name              object
# CreditScore        int64
# Country           object
# Gender            object
# Age                int64
# Tenure             int64
# Balance          float64
# NumOfProducts      int64
# Salary           float64
# Exited             int64
# dtype: object

# %%
'''
row_to_check = {'CustomerId':15634602, 'Name':'Hargrave'}
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum()>1
print('Is_row_is_duplicated: ', is_duplicated)'''

row_to_check = {'CustomerId': 15634602, 'Name': 'Hargrave'}
is_duplicated = df.eq(pd.Series(row_to_check)).all(axis=1).sum()>1
print(is_duplicated)
# Out:
# False

# %%
print(df)
# Out:
#       CustomerId       Name  CreditScore  Country  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619   France  Female   42       2
# 1       15634602   Hargrave          619   France  Female   42       2
# 2       15634602       Onio          502   France  Female   42       8
# 3       15634602       Onio          502   France  Female   42       8
# 4       15737888   Mitchell          850    Spain  Female   43       2
# ...          ...        ...          ...      ...     ...  ...     ...
# 9994    15719294       Wood          800   France  Female   29       2
# 9995    15606229   Obijiaku          771   France    Male   39       5
# 9996    15569892  Johnstone          516   France    Male   35      10
# 9997    15569892  Johnstone          516   France    Male   35      10
# 9998    15682355  Sabbatini          772  Germany    Male   42       3
#
#         Balance  NumOfProducts     Salary  Exited
# 0          0.00              1  101348.88       1
# ...

# %%
print(df.dtypes)
# Out:
# CustomerId         int64
# Name              object
# CreditScore        int64
# Country           object
# Gender            object
# Age                int64
# Tenure             int64
# Balance          float64
# NumOfProducts      int64
# Salary           float64
# Exited             int64
# dtype: object

# %%
row_to_check = {'CustomerId':15634602, 'Name':'Hargrave'}

df_filtered = df[['CustomerId', 'Name']]
is_duplicated = (row_to_check == df_filtered).all(axis = 1).sum()>1
print(is_duplicated)
# Out:
# True

# %%
#15569892  Johnstone

row_to_check = {'CustomerId':15569892 , 'Name': 'Johnstone'}
df_filtered = df[['CustomerId', 'Name']]
is_duplicated = (row_to_check == df_filtered).all(axis = 1).sum()>1
print(is_duplicated)
# Out:
# True

# %% [markdown]
# row_to_check = {'CreaditScore':502, }

# %%
#502   France
row_to_check = {'CreditScore': 502, 'Country':'France'}
df_filtered = df[['CreditScore', 'Country']]
is_duplicated = (row_to_check == df_filtered ).all(axis = 1).sum()>1
print(is_duplicated)
# Out:
# True
