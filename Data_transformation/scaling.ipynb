# %%
import pandas as pd
file_path = r"C:\Users\Sivaraman\Desktop\study\data analytics\practice\files_from_df.xlsx"
df = pd.read_excel(file_path)
print(df)
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
df1 = df.copy

# %%
print(df1)
# Out:
# <bound method NDFrame.copy of      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
import inspect
from sklearn.preprocessing import MinMaxScaler

# Get the source code of MinMaxScaler
print(inspect.getsource(MinMaxScaler))
# just i checked what there in inside of class.
# Out:
# class MinMaxScaler(OneToOneFeatureMixin, TransformerMixin, BaseEstimator):
#     """Transform features by scaling each feature to a given range.
#
#     This estimator scales and translates each feature individually such
#     that it is in the given range on the training set, e.g. between
#     zero and one.
#
#     The transformation is given by::
#
#         X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#         X_scaled = X_std * (max - min) + min
#
#     where min, max = feature_range.
#
#     This transformation is often used as an alternative to zero mean,
#     unit variance scaling.
#
#     `MinMaxScaler` doesn't reduce the effect of outliers, but it linearly
#     scales them down into a fixed range, where the largest occurring data point
#     corresponds to the maximum value and the smallest one corresponds to the
#     minimum value. For an example visualization, refer to :ref:`Compare
# ...

# %%
#from sklearn.preprocessing import MinMaxScaler
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
#df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
'''df1 = df1.apply(pd.to_numeric, errors='coerce')  # Convert non-numeric values to NaN
df1 = df1.fillna(0)  # Replace NaN values with 0'''
df1 = df1.apply(pd.to_numeric, errors = 'coerce').fillna(0)

df_scaled = pd.DataFrame(scalar.fit_transform(df1), columns = df.columns)
print(df_scaled)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 8
#       5 #df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
#       6 '''df1 = df1.apply(pd.to_numeric, errors='coerce')  # Convert non-numeric values to NaN
#       7 df1 = df1.fillna(0)  # Replace NaN values with 0'''
# ----> 8 df1 = df1.apply(pd.to_numeric, errors = 'coerce').fillna(0)
#      10 df_scaled = pd.DataFrame(scalar.fit_transform(df1), columns = df.columns)
#      11 print(df_scaled)
#
# AttributeError: 'function' object has no attribute 'apply'

# %%
print(df
     )
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
df2 = df[['CreditScore', 'Salary']]
print(df2)
# Out:
#      CreditScore     Salary
# 0            619  101348.88
# 1            619  101348.88
# 2            502  112542.58
# 3            502  112542.58
# 4            850   79084.10
# ..           ...        ...
# 448          675  138777.00
# 449          778  124694.99
# 450          494   40084.32
# 451          850  119232.33
# 452          592   43921.36
#
# [453 rows x 2 columns]

# %%
print(df2.dtypes)
# Out:
# CreditScore      int64
# Salary         float64
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 13
#       1 '''#from sklearn.preprocessing import MinMaxScaler
#       2 import pandas as pd
#       3 from sklearn.preprocessing import MinMaxScaler
#    (...)
#      10 df_scaled = pd.DataFrame(scalar.fit_transform(df1), columns = df.columns)
#      11 print(df_scaled)'''
# ---> 13 from sklearn.preprocessing import MinMaxScalar
#      14 import pandas as pd
#      15 df2 = df2.apply(pd.to_numeric, errors = 'coerce').fillna(0)
#
# ImportError: cannot import name 'MinMaxScalar' from 'sklearn.preprocessing' (C:\Users\Sivaraman\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
'''import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Assuming you've already loaded your dataset into df
df = pd.read_csv("your_data.csv")  # Replace with your actual data source

# Define the columns you want to scale
columns_to_scale = ["CreditScore", "Age", "Balance", "Salary", "Loan_Amount"]

# Initialize the scaler
scaler = MinMaxScaler()

# Apply scaling only to selected columns
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Display the first few rows to verify
print(df.head())
'''
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
columns_to_scale = ['CreditScore', 'Age', 'Balance', 'Salary', 'Loan_Amount']
scaler = MinMaxScaler()
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
df_scaled = df.copy()

print(df.head)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[34], line 32
#      30 columns_to_scale = ['CreditScore', 'Age', 'Balance', 'Salary', 'Loan_Amount']
#      31 scaler = MinMaxScaler()
# ---> 32 df[columns_to_scale] = scaler.inverse_transform(df[columns_to_scale])
#      33 print(df.head)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_data.py:569, in MinMaxScaler.inverse_transform(self, X)
#     556 def inverse_transform(self, X):
#     557     """Undo the scaling of X according to feature_range.
#     558
#     559     Parameters
#    (...)
#     567         Transformed data.
#     568     """
# --> 569     check_is_fitted(self)
#     571     xp, _ = get_namespace(X)
#     573     X = check_array(
#     574         X,
#     575         copy=self.copy,
#    (...)
#     578         ensure_all_finite="allow-nan",
#     579     )
# ...

# %%
'''import os

# Define the folder path where you want to save the file
folder_path = "C:/Users/YourName/Documents/MyData"  # Change to your desired path

# Ensure the folder exists (creates it if not)
os.makedirs(folder_path, exist_ok=True)

# Define the full file path
file_path = os.path.join(folder_path, "my_data.csv")

# Save DataFrame as a CSV file
df.to_csv(file_path, index=False)  

print(f"File saved at: {file_path}")
'''
import os
folder_path = r"C:\Users\Sivaraman\Desktop\study\data analytics\practice"
file_path = os.path.join(folder_path, "scaled_data.csv")
df.to_csv(file_path, index = False)
print('file saved')
# Out:
# file saved

# %%
'''import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Sample DataFrame
df = pd.DataFrame({
    "CreditScore": [619, 619, 502],
    "Age": [42, 42, 42],
    "Balance": [0, 0, 159660.8],
    "Salary": [101348.88, 101348.88, 112542.58],
    "Loan_Amount": [20269.776, 20269.776, 22508.516]
})

# Define columns to scale
columns_to_scale = ["CreditScore", "Age", "Balance", "Salary", "Loan_Amount"]

# Initialize and fit the scaler
scaler = MinMaxScaler()
df_scaled = df.copy()  # Copy original dataframe
df_scaled[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

# Reverse the scaling (convert back)
df_original = df_scaled.copy()
df_original[columns_to_scale] = scaler.inverse_transform(df_scaled[columns_to_scale])

# Display original values
print(df_original.head())'''
#---------------------------------------------
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
columns_to_scale = ["CreditScore", "Age", "Balance", "Salary", "Loan_Amount"]

scaler = MinMaxScaler()
df_scaled = df.copy()
df_scaled[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])

df_original = df_scaled.copy()
df_original[columns_to_scale] = scaler.inverse_transform(df[columns_to_scale])
print(df_original.head())
# Out:
#    CustomerId      Name  CreditScore Country  Gender       Age  Tenure  \
# 0    15634602  Hargrave     0.512658  France  Female  0.377049       2
# 1    15634602  Hargrave     0.512658  France  Female  0.377049       2
# 2    15634602      Onio     0.265823  France  Female  0.377049       8
# 3    15634602      Onio     0.265823  France  Female  0.377049       8
# 4    15737888  Mitchell     1.000000   Spain  Female  0.393443       2
#
#     Balance  NumOfProducts    Salary  ... numeric_gender GenderNumeric  \
# 0  0.000000              1  0.506524  ...              0             0
# 1  0.000000              1  0.506524  ...              0             0
# 2  0.749067              3  0.562674  ...              0             0
# 3  0.749067              3  0.562674  ...              0             0
# 4  0.588848              1  0.394840  ...              0             0
#
#     Age_group  Salary_Level  countrys_Id Countrys_Id Monthly_Salary  \
# ...

# %%
print(df1)
# Out:
# <bound method NDFrame.copy of      CustomerId        Name  CreditScore  Country  Gender       Age  Tenure  \
# 0      15634602    Hargrave     0.512658   France  Female  0.377049       2
# 1      15634602    Hargrave     0.512658   France  Female  0.377049       2
# 2      15634602        Onio     0.265823   France  Female  0.377049       8
# 3      15634602        Onio     0.265823   France  Female  0.377049       8
# 4      15737888    Mitchell     1.000000    Spain  Female  0.393443       2
# ..          ...         ...          ...      ...     ...       ...     ...
# 448    15694860    Uspensky     0.630802   France  Female  0.311475       6
# 449    15658169        Cook     0.848101    Spain  Female  0.459016       6
# 450    15794396     Newbold     0.248945  Germany  Female  0.311475       7
# 451    15785798  Uchechukwu     1.000000   France    Male  0.344262       9
# 452    15710825       Ch'en     0.455696    Spain    Male  0.196721       7
#
# ...

# %%
import pandas as pd
file_path = r"C:\Users\Sivaraman\Desktop\study\data analytics\Data (for practice)\bank_details_withdate.xlsx"
df = pd.read_excel(file_path)
print(df)
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary       Date      Dep
# ...

# %%
# Out:
# <bound method NDFrame.head of      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary       Date      Dep  Scaled_salary
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
scaler = MinMaxScaler()
df['Balance_Scaled'] = scaler.fit_transform(df[['Balance']]) 
df['CreditScore_scaled'] = scaler.fit_transform(df[['CreditScore']])

print(df.head)
# Out:
# <bound method NDFrame.head of      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary       Date      Dep  Scaled_salary  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

scaler = StandardScaler()
df['Salary_standardize'] = scaler.fit_transform(df[['Salary']])
print(df.head)

'''columns_to_standardize = ["CreditScore", "Age", "Balance", "Salary", "Loan_Amount"]

# Initialize the scaler
scaler = StandardScaler()

# Apply standardization
df_standardized = df.copy()
df_standardized[columns_to_standardize] = scaler.fit_transform(df[columns_to_standardize])

# Display standardized data
print(df_standardized.head())'''
# Out:
# <bound method NDFrame.head of      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary       Date      Dep  Scaled_salary  \
# ...

# %%
print(df)
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary       Date      Dep  Scaled_salary  \
# ...

# %%
'''pivot_df = df.pivot(index=["CustomerId", "Name"], columns="Date", values="Salary")
print(pivot_df)
'''
'''pivot_df = df.pivot(index = ['CustomerId', 'Name', 'Age'], columns = 'Date', values = 'Salary')
print(pivot_df)'''

pivot_df = df.pivot(index = ['CustomerId'], columns = 'Salary', values = 'Age')
print(pivot.df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 7
#       1 '''pivot_df = df.pivot(index=["CustomerId", "Name"], columns="Date", values="Salary")
#       2 print(pivot_df)
#       3 '''
#       4 '''pivot_df = df.pivot(index = ['CustomerId', 'Name', 'Age'], columns = 'Date', values = 'Salary')
#       5 print(pivot_df)'''
# ----> 7 pivot_df = df.pivot(index = ['CustomerId'], columns = 'Salary', values = 'Age')
#       8 print(pivot.df)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# ...
