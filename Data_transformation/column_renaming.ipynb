# %%
import pandas as pd
file_path = r"C:\Users\Sivaraman\Desktop\study\data analytics\practice\files_from_df.xlsx"
df = pd.read_excel(file_path)
print(df)
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
'''df.rename(columns={
    "CustomerId": "Customer_ID",
    "CreditScore": "Credit_Score",
    "NumOfProducts": "Num_Products"
}, inplace=True)'''

print(df.head())
# Out:
#    CustomerId      Name  CreditScore Country  Gender  Age  Tenure    Balance  \
# 0    15634602  Hargrave          619  France  Female   42       2       0.00
# 1    15634602  Hargrave          619  France  Female   42       2       0.00
# 2    15634602      Onio          502  France  Female   42       8  159660.80
# 3    15634602      Onio          502  France  Female   42       8  159660.80
# 4    15737888  Mitchell          850   Spain  Female   43       2  125510.82
#
#    NumOfProducts     Salary  ... numeric_gender GenderNumeric   Age_group  \
# 0              1  101348.88  ...              0             0  Middle_Age
# 1              1  101348.88  ...              0             0  Middle_Age
# 2              3  112542.58  ...              0             0  Middle_Age
# 3              3  112542.58  ...              0             0  Middle_Age
# 4              1   79084.10  ...              0             0  Middle_Age
#
# ...

# %%
print(df.columns)
# Out:
# Index(['CustomerId', 'Name', 'CreditScore', 'Country', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'Salary', 'Date', 'Dep', 'Year',
#        'Month', 'Day', 'Weekday', 'categorized_credit_score', 'numeric_gender',
#        'GenderNumeric', 'Age_group', 'Salary_Level', 'countrys_Id',
#        'Countrys_Id', 'Monthly_Salary', 'FullName', 'Credit_Category',
#        'Loan_Amount'],
#       dtype='object')

# %%
#Column Renaming
df.rename(columns = {'CustomerId':'Customer_Id',
                    'Name':'Full_Name', 'Creditscore':'Credit_Score'})
# Out:
#      Customer_Id   Full_Name  CreditScore  Country  Gender  Age  Tenure  \
# 0       15634602    Hargrave          619   France  Female   42       2
# 1       15634602    Hargrave          619   France  Female   42       2
# 2       15634602        Onio          502   France  Female   42       8
# 3       15634602        Onio          502   France  Female   42       8
# 4       15737888    Mitchell          850    Spain  Female   43       2
# ..           ...         ...          ...      ...     ...  ...     ...
# 448     15694860    Uspensky          675   France  Female   38       6
# 449     15658169        Cook          778    Spain  Female   47       6
# 450     15794396     Newbold          494  Germany  Female   38       7
# 451     15785798  Uchechukwu          850   France    Male   40       9
# 452     15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  NumOfProducts     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
df.rename(columns = {'NumOfProducts':'Num_Of_Products'})
# Out:
#      CustomerId        Name  CreditScore  Country  Gender  Age  Tenure  \
# 0      15634602    Hargrave          619   France  Female   42       2
# 1      15634602    Hargrave          619   France  Female   42       2
# 2      15634602        Onio          502   France  Female   42       8
# 3      15634602        Onio          502   France  Female   42       8
# 4      15737888    Mitchell          850    Spain  Female   43       2
# ..          ...         ...          ...      ...     ...  ...     ...
# 448    15694860    Uspensky          675   France  Female   38       6
# 449    15658169        Cook          778    Spain  Female   47       6
# 450    15794396     Newbold          494  Germany  Female   38       7
# 451    15785798  Uchechukwu          850   France    Male   40       9
# 452    15710825       Ch'en          592    Spain    Male   31       7
#
#        Balance  Num_Of_Products     Salary  ... numeric_gender GenderNumeric  \
# ...

# %%
df.coulumns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8852\1529837416.py in ?()
# ----> 1 df.coulumns
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coulumns'

# %%
print(df.columns)
# Out:
# Index(['CustomerId', 'Name', 'CreditScore', 'Country', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'Salary', 'Date', 'Dep', 'Year',
#        'Month', 'Day', 'Weekday', 'categorized_credit_score', 'numeric_gender',
#        'GenderNumeric', 'Age_group', 'Salary_Level', 'countrys_Id',
#        'Countrys_Id', 'Monthly_Salary', 'FullName', 'Credit_Category',
#        'Loan_Amount'],
#       dtype='object')

# %%
new_order = ['CustomerId', 'Name','Age','Gender','Country', 'CreditScore' ]
df = df[new_order]

# %%
print(df)
# Out:
#      CustomerId        Name  Age  Gender  Country  CreditScore
# 0      15634602    Hargrave   42  Female   France          619
# 1      15634602    Hargrave   42  Female   France          619
# 2      15634602        Onio   42  Female   France          502
# 3      15634602        Onio   42  Female   France          502
# 4      15737888    Mitchell   43  Female    Spain          850
# ..          ...         ...  ...     ...      ...          ...
# 448    15694860    Uspensky   38  Female   France          675
# 449    15658169        Cook   47  Female    Spain          778
# 450    15794396     Newbold   38  Female  Germany          494
# 451    15785798  Uchechukwu   40    Male   France          850
# 452    15710825       Ch'en   31    Male    Spain          592
#
# [453 rows x 6 columns]
