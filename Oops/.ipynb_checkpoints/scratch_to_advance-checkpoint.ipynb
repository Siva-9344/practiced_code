# %%
#__init__ Method
'''
The __init__ method is a special method in Python used as a constructor. 
It's called automatically when a new instance of the class is created. 
The purpose of the __init__ method is to initialize the properties of the object (in this case, name and age).
'''

# self
'''
self is a reference to the instance of the class. It allows you to access instance variables and methods inside the class.

In your code, self.name refers to the name attribute of the specific instance, and self.age refers to the age attribute of the specific instance.

You use self to access or modify the object’s attributes within class methods.
'''


# Example 1: Simple Class with Properties and Method

'''
class Person:
    # Constructor to initialize properties
    def __init__(self, name, age):
        self.name = name  # Property
        self.age = age  # Property

    # Method to print a greeting
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating objects (instances) of the class
person1 = Person("Alice", 25)
person2 = Person("Bob", 30)

# Calling the greet method using objects
person1.greet()  # Output: Hello, my name is Alice and I am 25 years old.
person2.greet()  # Output: Hello, my name is Bob and I am 30 years old.

'''
class person:
    def __init__(self, name, age): # Constructor to initialize properties
        self.name = name
        self.age = age
    def greet(self):
        print(f'hello, my name is {self.name} and i am {self.age} years old')

person1 = person('Alice', 25)
person2 = person('Ram', 22)

person1.greet()
person2.greet()
# Out:
# hello, my name is Alice and i am 25 years old
# hello, my name is Ram and i am 22 years old

# %%
# Example 2: Class with Methods to Perform Actions

'''
class BankAccount:
    # Constructor to initialize account balance
    def __init__(self, balance=0):
        self.balance = balance  # Property to store account balance

    # Method to deposit money
    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited {amount}. New balance is {self.balance}.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance is {self.balance}.")
        else:
            print("Insufficient funds.")

    # Method to check balance
    def check_balance(self):
        print(f"Current balance: {self.balance}")

# Creating an object of BankAccount
account = BankAccount()

# Using the object's methods
account.deposit(1000)  # Deposits money
account.withdraw(500)  # Withdraws money
account.check_balance()  # Shows current balance

'''

print()

class bankaccount:
    def __init__(self, balance = 0):
        self.balance = balance
    def deposit(self,amount):
        self.balance = self.balance + amount
        print(f'deposit amount{amount}. New balance {self.balance}')
    def withdraw(self, amount):
        if amount <=self.balance:
            self.balance = self.balance - amount
            print(f'withdraw amount {amount}. balance amount {self.balance}')
        else:
            print('insufficient balance')
    def checkbalance(self)     :
        print(f'balance amount{self.balance}')

account = bankaccount()
account.deposit(5000)
account.withdraw(200)
account.checkbalance()
# Out:
# deposit amount5000. New balance 5000
# withdraw amount 200. balance amount 4800
# balance amount4800

# %%
# Example 3: Class with Multiple Objects
# Create a Car class with properties like make, model, and a method to display the car's information.

'''
class Car:
    def __init__(self, make, model):
        self.make = make  # Property
        self.model = model  # Property

    def display_info(self):
        print(f"Car Make: {self.make}, Model: {self.model}")

# Creating objects for different cars
car1 = Car("Toyota", "Corolla")
car2 = Car("Honda", "Civic")

# Calling the method for each object
car1.display_info()  # Output: Car Make: Toyota, Model: Corolla
car2.display_info()  # Output: Car Make: Honda, Model: Civic

'''

class car:
    def __init__(self, make, model):
        self.make = make
        self.model = model
    def display_info(self):
        print(f'make: {self.make}, model : {self.model}')

car1 = car('benz', 420)
car2 = car('TATA', 'Nexon')
car3 = car('Mahendhira', 'u700')

car1.display_info()
car2.display_info()
car3.display_info()
# Out:
# make: benz, model : 420
# make: TATA, model : Nexon
# make: Mahendhira, model : u700

# %%
# Example 5: Modifying Object Properties After Creation
# You can change an object's properties after it has been created.

'''
class Student:
    def __init__(self, name, grade):
        self.name = name  # Property
        self.grade = grade  # Property

    def display_info(self):
        print(f"Student: {self.name}, Grade: {self.grade}")

# Creating an object of Student
student = Student("John", "A")

# Displaying initial information
student.display_info()  # Output: Student: John, Grade: A

# Modifying the object's property
student.grade = "B"

# Displaying updated information
student.display_info()  # Output: Student: John, Grade: B

'''


class student:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade
    def display_info(self):
        print(f'student name {self.name}, grade{self.grade}')

# creating object
student1 = student('Ram', 'A')

# calling object
student1.display_info()

student1.grade = 'B' # # Modifying the object's property
student1.display_info()

student1.name = 'siva' # Modifying the object's property
student1.display_info()
# Out:
# student name Ram, gradeA
# student name Ram, gradeB
# student name siva, gradeB

# %%
'''
Practice Tasks:
Create a class called Book with properties title, author, and price. Add a method to display the book's details.

Create a Person class with first_name, last_name, and email. Add a method that returns the full name (first + last name) and a method that sends an email.

Create a Product class with properties product_name, price, and quantity. Add methods for calculating the total cost and checking if the product is in stock.
'''
# Out:
# "\nPractice Tasks:\nCreate a class called Book with properties title, author, and price. Add a method to display the book's details.\n\nCreate a Person class with first_name, last_name, and email. Add a method that returns the full name (first + last name) and a method that sends an email.\n\nCreate a Product class with properties product_name, price, and quantity. Add methods for calculating the total cost and checking if the product is in stock.\n"

# %%
# Task
# Create a class called Book with properties title, author, and price. Add a method to display the book's details.

class book:
    def __init__(self, tittle, author, price):
        self.tittle = tittle
        self.author = author
        self.price = price
    def display_book(self):
        print(f'book name :{self.tittle}, author: {self.author}, price : {self.price}.')

book1 = book('siva', 'book x', 300)
book1.display_book()
# Out:
# book name :siva, author: book x, price : 300.

# %%
# Task 2
''' Create a Person class with first_name, last_name, and email. Add a method that returns the full name (first + last name) and 
a method that sends an email.'''

class person:
    def __init__(self, first_name, last_name, mail):
        self.first_name = first_name
        self.last_name = last_name
        self.mail = mail
    def fullname(self):
        print(f'my name is {self.first_name + self.last_name}.')
    def send_mail(self):
        print(f'send the mail {self.mail}')


# creating object
person1 = person('siva','raman', 'siva123@gmail.com')

# calling object
person1.fullname()
person1.send_mail()
# Out:
# my name is sivaraman.
# send the mail siva123@gmail.com

# %%
'''
Create a Product class with properties product_name, price, and quantity.
Add methods for calculating the total cost and checking if the product is in stock. and add some extra task
'''
class Product:
    def __init__(self, product_name, price, quantity, discount):
        self.product_name = product_name
        self.price = price
        self.quantity = quantity
        self.discount = discount
        
    def total_cost(self):
        print(f'Product totalcost : {self.price * self.quantity}')
    def check_stock(self):
        if self.quantity > 0:
            print(f'Stock is available : {self.quantity} items left')
        else:
            print('stock is not available')
    def apply_discount(self):    
        if self.discount > 0:
            self.price = self.price - ((self.price/100)*self.discount) # updated price after discount

product1 = Product('mobile', 25000, 20,0)
product2 = Product('lap', 50000, 0,0)
product3 = Product('modem', 3000, 2,0)
product4 = Product('spk',2000, 10, 10)

product1.total_cost()
product2.check_stock()
product3.check_stock()
product4.apply_discount()
print('After applied discount price : ',product4.price)
# Out:
# Product totalcost : 500000
# stock is not available
# Stock is available : 2 items left
# After applied discount price :  1800.0

# %%
'''
Example 1: Adding and Removing Products
Task:

Create a Product class with properties like name, price, and quantity.

Create a Cart class with the ability to:

Add products using append().

Remove products using remove().
'''
'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    
    def display(self):
        print(f'Product: {self.name}, Price: {self.price}, Quantity: {self.quantity}')
'''
class Product:
    def __init__(self,name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def display(self):
        print(f'Product: {self.name}, Price: {self.price}, Quantity: {self.quantity}')

'''
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    
    def display(self):
        print(f'Product: {self.name}, Price: {self.price}, Quantity: {self.quantity}')

class Cart:
    def __init__(self):
        self.cart_items = []
    
    def add_product(self, product):
        self.cart_items.append(product)
    
    def remove_product(self, product_name):
        for product in self.cart_items:
            if product.name == product_name:
                self.cart_items.remove(product)
                print(f'{product_name} removed from the cart.')
                break
        else:
            print(f'{product_name} not found in the cart.')

    def display_cart(self):
        print("Cart contains:")
        for product in self.cart_items:
            product.display()

'''
class Cart:
    def __init__(self):
        self.cart_items = []
    def add_products(self, products):
        self.cart_items.append(products)
    def remove_products(self, product_name):
        for product in self.cart_items:
            if product.name == product_name:
                self.cart_items.remove(product)
                print(f'{product_name} removed from the cart.')
                break
        else:
            print(f'{product_name} not found in cart.')

    def calculate_total(self):
        total_price = sum([product.price * product.quantity for product in self.cart_items])
        if total_price > 50000:
            total_price = total_price * 0.9 # for 10 % discount is applied
            print()
            print('10% discount is applied')
        return total_price    
            
        
    def display_cart(self):
        print('cart contains :')
        print()
        for product in self.cart_items:
            product.display()
'''
# Create product objects
product1 = Product('Phone', 10000, 2)
product2 = Product('Laptop', 50000, 1)

# Create cart object and perform operations
cart = Cart()
cart.add_product(product1)
cart.add_product(product2)

cart.display_cart()

cart.remove_product('Phone')
cart.display_cart()
'''

product1 = Product('mobile', 12000, 12)
product2 = Product('spk', 1200, 15)
product3 = Product('game_station', 22000, 5)

cart = Cart()
cart.add_products(product1)
cart.add_products(product2)
cart.add_products(product3)

print()

cart.display_cart()
cart.remove_products('mobile')
cart.display_cart()                 # its work perfectly

total = cart.calculate_total()
print(f'total cart price after discount {total}')
# Out:
# cart contains :
#
# Product: mobile, Price: 12000, Quantity: 12
# Product: spk, Price: 1200, Quantity: 15
# Product: game_station, Price: 22000, Quantity: 5
# mobile removed from the cart.
# cart contains :
#
# Product: spk, Price: 1200, Quantity: 15
# Product: game_station, Price: 22000, Quantity: 5
#
# 10% discount is applied
# total cart price after discount 115200.0

# %%
print('1000')
print(1000*0.9)
# Out:
# 1000
# 900.0

# %%
# Task 1: Create and Manage Cart Items
'''
Create a Product class with the properties name, price, quantity.

Create a Cart class that allows:

Adding a product to the cart.

Removing a product from the cart by its name.

Displaying all products in the cart.

Calculating the total price of products in the cart.

Applying a 15% discount to the total price if it exceeds 30,000.
'''

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def display(self):
        print(f'product: {self.name}, Price: {self.price}, Quantity: {self.quantity}')

class Cart:
    def __init__(self):
        self.cart_items = []
        
    def add_products(self, products):
        self.cart_items.append(products)
        print('Product is succesfully added')
        
    def remove_products(self, product_name):
        for product in self.cart_items:
            if product.name == product_name:
                self.cart_items.remove(product)
                print(f'{product_name} removed from the cart')
                break
        else:
            print(f'{product_name} is not found')
            
    def show_cartitems(self):       
        print('cart_contains :')
        for product in self.cart_items:
            product.display()
            
    def total_calculate(self):
        total = sum([product.price * product.quantity for product in self.cart_items ])
        if total > 30000:
            total = total * 0.85
            print('15% discount is aplied')
        return total    
product1 = Product('Book', 400, 20)
product2 = Product('Pen', 5, 100)
product3 = Product('lap', 45000, 15)
            
product1.display()
product2.display()
product3.display()

print()
print()

cart = Cart()
cart.add_products(product1)
cart.add_products(product2)
cart.add_products(product3)
print()
cart.total_calculate()
print()
cart.remove_products('Book')
cart.show_cartitems()         # its work perfectly
# Out:
# product: Book, Price: 400, Quantity: 20
# product: Pen, Price: 5, Quantity: 100
# product: lap, Price: 45000, Quantity: 15
#
#
# Product is succesfully added
# Product is succesfully added
# Product is succesfully added
#
# 15% discount is aplied
#
# Book removed from the cart
# cart_contains :
# product: Pen, Price: 5, Quantity: 100
# product: lap, Price: 45000, Quantity: 15

# %%
print(1-(10/100))
print(0.9*20000)
# Out:
# 0.9
# 18000.0

# %%
# The if __name__ == "__main__": construct is called a "main check" or "entry point check".
'''
Conclusion:
When you run the file directly (e.g., python example.py), the code inside if __name__ == "__main__": will run.

When you import that file into another file (e.g., import example), the code inside if __name__ == "__main__": will not run automatically.
'''
# Out:
# '\nConclusion:\nWhen you run the file directly (e.g., python example.py), the code inside if __name__ == "__main__": will run.\n\nWhen you import that file into another file (e.g., import example), the code inside if __name__ == "__main__": will not run automatically.\n'

# %%
# Practice Task

# A Product class with per-product discounts.
# A Cart class that handles product additions, discounted pricing, display, and saving to file.

'''
class Product:
    def __init__(self, name, price, quantity, discount=0):
        self.name = name
        self.price = price
        self.quantity = quantity
        self.discount = discount  # in percentage

    def get_discounted_price(self):
        """Apply discount and return final price per unit."""
        return self.price * (1 - self.discount / 100)

    def get_total_price(self):
        """Final discounted price multiplied by quantity."""
        return self.get_discounted_price() * self.quantity
'''

class Product:
    def __init__(self, name, price, quantity, discount = 0):
        self.name = name
        self.price = price
        self.quantity = quantity
        self.discount = discount
        
    def get_discounted_price(self):
        return self.price * (1- self.discount/100)
        
    def get_total_price(self):
        return self.get_discounted_price()* self.quantity
'''
class Cart:
    def __init__(self):
        self.items = []

    def add_product(self, product):
        self.items.append(product)

''' 
class Cart:
    def __init__(self):
        self.items = []
        
    def add_product(self, product):
        self.items.append(product)
        
    def display_cart(self):
        print('Cart Summary')
        for item in self.items:
            discounted_price = item.get_discounted_price()
            total_price = item.get_total_price()
            print(f"{item.name} - Quantity: {item.quantity},"
                 f"Price after discount {item.discount}% discount: {discounted_price:.2f} each, "
                 f"Total : {total_price:.2f}")
        print('')
        
    def  calculate_total(self):
         total = sum(item.get_total_price() for item in self.items)
         print(f"Final Cart Total : {total:.2f}")
         return total
        
    def save_to_file(self, file_name = 'cart_summary.txt'):
        with open(file_name, 'w') as file:
            file.write('cart summary: \n')
            for item in self.items:
                discounted_price = item.get_discounted_price()
                total_price = item.get_total_price()
                file.write(f"{item.name} - Quantity: {item.quantity},"
                          f"Price after {item.discount}% discount: {discounted_price:.2f} each,"
                          f"Total: {total_price:.2f}\n")
            file.write("\n")
            file.write(f"Final Cart Total: {self.calculate_total():.2f}\n")
'''
# ✅ Example Usage:
if __name__ == "__main__":
    # Create products
    mobile = Product(name="Mobile", price=20000, quantity=2, discount=10)  # 10% discount
    laptop = Product(name="Laptop", price=50000, quantity=1, discount=20)  # 20% discount

    # Add to cart
    cart = Cart()
    cart.add_product(mobile)
    cart.add_product(laptop)
'''
if __name__ == "__main__":
    mobile = Product(name = 'Mobile', price = 25000, quantity = 4, discount = 10)
    laptop = Product(name = 'Laptop', price = 45000, quantity = 15, discount = 5)
    speaker = Product(name = 'speaker', price = 1200, quantity = 25)
    
    # Add cart
    cart = Cart()
    cart.add_product(mobile)
    cart.add_product(laptop)
    cart.add_product(speaker)

    # # Show cart with discounted prices
    cart.display_cart()
    
    print('Total: ')
    cart.calculate_total()
    
    cart.save_to_file()
# Out:
# Cart Summary
# Mobile - Quantity: 4,Price after discount 10% discount: 22500.00 each, Total : 90000.00
# Laptop - Quantity: 15,Price after discount 5% discount: 42750.00 each, Total : 641250.00
# speaker - Quantity: 25,Price after discount 0% discount: 1200.00 each, Total : 30000.00
#
# Total:
# Final Cart Total : 761250.00

# %%
with open('cart_summary.txt', 'r') as file:
    print("\nFile Content:\n")
    print(file.read())
# Out:
# File Content:
#
# cart summary:
# Mobile - Quantity: 4,Price after 10% discount: 22500.00 each,Total: 90000.00
# Laptop - Quantity: 15,Price after 5% discount: 42750.00 each,Total: 641250.00
# speaker - Quantity: 25,Price after 0% discount: 1200.00 each,Total: 30000.00
#
# Final Cart Total: 761250.00

# %%
#  Inventory and Order System – Full Code

class Product:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock
        
    def check_stock(self, quantity):
        return self.stock >= quantity
        
    def reduce_stock(self, quantity):
        if self.check_stock(quantity):
            self.stock = self.stock - quantity
            return True
        else:
            return False

class CartItem:
    def __init__(self, product, quantity):
        self.product = product
        self.quantity = quantity
    def get_item_total(self):
        return self.product.price * self.quantity


class Cart: # customer cart
    def __init__(self):
        self.items = [] # Store the products the customer wants to buy — not the shop's stock.

    def add_items(self, product, quantity):
        if product.check_stock(quantity):
            product.reduce_stock(quantity)  # thi line for reduce stock in shop after customer bought 
            cart_item = CartItem(product, quantity)
            self.items.append(cart_item)
            print(f"Added {quantity} x {product.name} to cart.")
        else:
            print(f"not enough stock for {product.name}. Available: {product.stock}, Requested : {quantity}")

    def display_cart(self):
        print('\nCart Summary: ')
        for item in self.items:
            print(f"{item.product.name} - Quantity : {item.quantity},"
                 f"Total : {item.get_item_total():.2f}")
        print(f"\nFinal Cart Total: {self.get_total_amount():.2f}\n")

    def get_total_amount(self):
        return sum(item.get_item_total()for item in self.items)


    def save_cart_to_file(self, filename = 'cart_summary.txt'):
        with open(filename, 'w') as f:
            f.write('Cart Summary: \n')
            for item in self.items:
                f.write(f"{item.product.name} - Quantity : {item.quantity},"
                f"Unit_price : {item.product.price:.2f},"
                f"Total: {item.get_item_total():.2f}\n")
        print(f"Cart saved to {filename}.")
        
#Next Task: Add a Simple User System (Multiple Users & Their Carts)
class User:
    def __init__ (self, name):
        self.name = name
        self.cart = Cart()
        
    def  add_to_cart(self, product, quantity):
        print(f"\n{self.name} is adding to cart: ")
        self.cart.add_items(product, quantity)
        
    def view_cart(self):    
        print(f"\n{self.name}'s cart")
        self.cart.display_cart()
    def save_cart(self):
        filename = f"{self.name}_cart_summary.txt"
        self.cart.save_cart_to_file(filename)
        

if __name__ == "__main__":
    mobile = Product('Mobile', 20000, 10)
    laptop = Product('laptop', 50000, 5)
    speaker = Product('Speaker', 1500, 20)
    
    user1 = User('Alice')
    user2 = User('Bob')
    user3 = User('Siva')
    
    user1.add_to_cart(mobile,2)
    user2.add_to_cart(laptop,3)
    user1.add_to_cart(laptop,1)
    user3.add_to_cart(laptop,1)
    
    user1.view_cart()
    user2.view_cart()
    user3.view_cart()
    
    user1.save_cart()
    user2.save_cart()
# Out:
# Alice is adding to cart:
# Added 2 x Mobile to cart.
#
# Bob is adding to cart:
# Added 3 x laptop to cart.
#
# Alice is adding to cart:
# Added 1 x laptop to cart.
#
# Siva is adding to cart:
# Added 1 x laptop to cart.
#
# Alice's cart
#
# Cart Summary:
# Mobile - Quantity : 2,Total : 40000.00
# laptop - Quantity : 1,Total : 50000.00
#
# Final Cart Total: 90000.00
#
#
# Bob's cart
#
# Cart Summary:
# laptop - Quantity : 3,Total : 150000.00
#
# Final Cart Total: 150000.00
#
#
# Siva's cart
#
# Cart Summary:
# laptop - Quantity : 1,Total : 50000.00
#
# Final Cart Total: 50000.00
#
# Cart saved to Alice_cart_summary.txt.
# Cart saved to Bob_cart_summary.txt.
