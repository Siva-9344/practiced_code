# %%
#Example Without __init__ (More Work)

'''class car:
    pass
car1 = car()
car1.brand = 'Audi'
car.color = 'black'
print(car1.brand)
print(car1.color)'''
# Out:
# Audi
# black

# %%
#Example With __init__ (Better & Automatic)

'''class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

car1 = Car("Toyota", "Red")  # No need to manually assign properties
print(car1.brand)  # Output: Toyota'''

class car:
    def __init__(self, brand, color, ml):
        self.brand = 'TATA'
        self.color = 'Green'
        self.ml = 35
       
print(car2.brand) 
print(car2.color)
# Out:
# TATA
# Green

# %%
'''
# Class (Blueprint for a car)
class Car:
    def __init__(self, brand, color):
        self.brand = brand  # Property (Attribute)
        self.color = color  # Property (Attribute)

    def start(self):
        print(f"{self.brand} car is starting...")

# Objects (Actual Cars)
car1 = Car("Toyota", "Red")
car2 = Car("Honda", "Blue")

print(car1.brand)  # Output: Toyota
print(car2.color)  # Output: Blue

car1.start()  # Output: Toyota car is starting...
car2.start()  # Output: Honda car is starting...
'''
class car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color
    def start(self):
        print(f'{self.brand} car is starting...')
        
car1 = car('Toyata','green')
car2 = car('tata', 'black')
car3 = car('benz','white')

car1.start()
car2.start()
car3.start()
# Out:
# Toyata car is starting...
# tata car is starting...
# benz car is starting...

# %%
#Example 2: Student (Simple Class and Object Example)
#Class → Student
#Objects → Different students with their names and marks

'''# Defining a class
class Student:
    def __init__(self, name, marks):
        self.name = name  # Attribute (Property)
        self.marks = marks  # Attribute (Property)

    def display(self):
        print(f"Student Name: {self.name}, Marks: {self.marks}")

# Creating objects
s1 = Student("John", 85)
s2 = Student("Alice", 90)

s1.display()  # Output: Student Name: John, Marks: 85
s2.display()  # Output: Student Name: Alice, Marks: 90
'''
class student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
    def display(self):
        print(f"student Name:{self.name}', Marks:{self.marks}")
# creating object
s1 = student('siva', 98)
s2 = student('guru',97)

s1.display()
s2.display()
# Out:
# student Name:siva', Marks:98
# student Name:guru', Marks:97

# %%
#Example 3: Bank Account (Class with Methods)
#Class → BankAccount
#Objects → Different bank accounts with balances

'''
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited. New Balance: {self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds!")
        else:
            self.balance -= amount
            print(f"{amount} withdrawn. Remaining Balance: {self.balance}")

# Creating objects (bank accounts)
acc1 = BankAccount("Rahul", 5000)
acc2 = BankAccount("Neha", 10000)

acc1.deposit(2000)   # Output: 2000 deposited. New Balance: 7000
acc2.withdraw(3000)  # Output: 3000 withdrawn. Remaining Balance: 7000
'''
class bankaccount:
    def __init__(self, acc_holder, balance):
        self.acc_holder = acc_holder
        self.balance = balance
    def deposite(self,amount):
        self.balance += amount
        print(f'deposited :{amount}. New_balance: {self.balance}')
    def withdrawn(self,amount):
        if amount > self.balance:
            print('insufficient balnce')
        else:
            self.balance -= amount
            print(f"withdrawn amount: {amount}. Remaining : {self.balance} ")
acc1 = bankaccount('rahul', 10000)
acc2 = bankaccount('siva', 12000)

acc1.deposite(2000)
acc2.withdrawn(1500)
# Out:
# deposited :2000. New_balance: 12000
# withdrawn amount: 1500. Remaining : 10500

# %%
#Example 4: Library Management System (Intermediate Level Example)

#Class → Book
#Objects → Different books in the library
#Functionality → Add books, issue books, and display available books
'''
class Library:
    def __init__(self):
        self.books = []  # List to store books
    
    def add_book(self, book_name):
        self.books.append(book_name)
        print(f"Book '{book_name}' added to the library.")
    
    def issue_book(self, book_name):
        if book_name in self.books:
            self.books.remove(book_name)
            print(f"Book '{book_name}' has been issued.")
        else:
            print(f"Sorry, Book '{book_name}' is not available.")
    
    def display_books(self):
        if not self.books:
            print("No books are available in the library.")
        else:
            print("Available Books:")
            for book in self.books:
                print("-", book)

# Creating Library Object
lib = Library()

# Adding Books
lib.add_book("Python Programming")
lib.add_book("Data Science")
lib.add_book("Machine Learning")

# Displaying Books
lib.display_books()

# Issuing a Book
lib.issue_book("Data Science")

# Displaying Books After Issue
lib.display_books()
'''

class library:
    def __init__(self):
        self.books = []
    def add_books(self, book_name):
        self.books.append(book_name)
        print(f'Book {book_name} is succesfully added')
    def issue_book(self, book_name):
        if book_name in self.books:
            self.books.remove(book_name)
            print(f"Book'{book_name}' is issued")
        else:
            print(f"sorry '{book_name}' is not available")
    def display_book(self):
        if not self.books:
            print("no books are available in library")
        else:
            for books in self.books:
                print('-->', books)
lib = library()
lib.add_books('python')
lib.add_books('Data science')
lib.add_books('ML')
lib.add_books('Deep learning')
lib.add_books('art of laziness')

lib.issue_book('python')
lib.issue_book('little')
lib.issue_book('ML')
lib.display_book()
# Out:
# Book python is succesfully added
# Book Data science is succesfully added
# Book ML is succesfully added
# Book Deep learning is succesfully added
# Book art of laziness is succesfully added
# Book'python' is issued
# sorry 'little' is not available
# Book'ML' is issued
# --> Data science
# --> Deep learning
# --> art of laziness

# %%
'''# Class to represent a Course
class Course:
    def __init__(self, course_name, course_code):
        self.course_name = course_name
        self.course_code = course_code

# Class to represent a Student
class Student:
    def __init__(self, name, roll_number):
        self.name = name
        self.roll_number = roll_number
        self.enrolled_courses = []  # List to store enrolled courses
    
    def enroll(self, course):
        self.enrolled_courses.append(course)
        print(f"{self.name} has enrolled in {course.course_name} ({course.course_code})")

    def display_courses(self):
        if not self.enrolled_courses:
            print(f"{self.name} is not enrolled in any courses.")
        else:
            print(f"{self.name}'s Enrolled Courses:")
            for course in self.enrolled_courses:
                print(f"- {course.course_name} ({course.course_code})")

# Class to represent a School
class School:
    def __init__(self, school_name):
        self.school_name = school_name
        self.students = []  # List to store students
        self.courses = []  # List to store courses

    def add_student(self, student):
        self.students.append(student)
        print(f"Student {student.name} (Roll No: {student.roll_number}) has been added to {self.school_name}")

    def add_course(self, course):
        self.courses.append(course)
        print(f"Course {course.course_name} ({course.course_code}) has been added to {self.school_name}")

    def display_students(self):
        if not self.students:
            print(f"No students are registered in {self.school_name}.")
        else:
            print(f"Students in {self.school_name}:")
            for student in self.students:
                print(f"- {student.name} (Roll No: {student.roll_number})")

    def display_courses(self):
        if not self.courses:
            print(f"No courses available in {self.school_name}.")
        else:
            print(f"Courses offered in {self.school_name}:")
            for course in self.courses:
                print(f"- {course.course_name} ({course.course_code})")

# Creating a School
school = School("ABC International School")

# Creating Courses
course1 = Course("Mathematics", "MATH101")
course2 = Course("Physics", "PHY102")
course3 = Course("Computer Science", "CS103")

# Adding Courses to School
school.add_course(course1)
school.add_course(course2)
school.add_course(course3)

# Creating Students
student1 = Student("Alice", 101)
student2 = Student("Bob", 102)

# Adding Students to School
school.add_student(student1)
school.add_student(student2)

# Enrolling Students in Courses
student1.enroll(course1)
student1.enroll(course3)
student2.enroll(course2)

# Displaying Data
school.display_students()
school.display_courses()
student1.display_courses()
student2.display_courses()
'''

class course:
    def __init__(self, course_name, course_code):
        self.course_name = course_name
        self.course_code = course_code
class student:
    def __init__(self, name, roll_number):
        self.name = name
        self.roll_number = roll_number
        self.enrolled_course = []
    def enroll(self, course):
        self.enrolled_course.append(course)
        print(f"{self.name} has enrolled in {course.course_name} ({course.course_code})")
    def display_course(self):
        if not self.enrolled_course:
            print(f"{self.name} is not enrolled in any course")
        else:
            print(f"{self.name}'s enrolled_courses")
            for course in self.enrolled_course:
                print(f"- {course.course_name}({course.course_code}")
class school:
    def __init__(self,school_name):
        self.school_name = school_name
        self.students = []
        self.courses = []
    def add_student(self,student):
        self.students.append(student)
        print(f"student {student.name} (Roll No: {student.roll_number}) has been added to {self.school_name}")
    def add_course(sel, course):
        self.courses.append(course)
        print(f"course {course.course_name} ({course.course_code}) has been added to {sel.schoo_name}")
    def display_students(self):
        if not self.students:
            print(f"No students are registered in {sel.school_name}")
        else:
            print(f"Students in {self.school_name}")
            for student in self.students:
                print(f"- {student.name} (Roll No: {student.roll_number})")
    def display_courses(self):
        if not self.course:
            print(f"No course available in {self.school_name}")
        else:
            print(f"course offered in {self.school_name}: ")
            for course in self.courses:
                print(f"- {course.course_name} ({course.course_code})")


school = school('ABC school')
course1 = Course("Mathematics", "MATH101")
course2 = Course("Physics", "PHY102")
course3 = Course("Computer Science", "CS103")

# Adding Courses to School
school.add_course(course1)
school.add_course(course2)
school.add_course(course3)

# Creating Students
student1 = Student("Alice", 101)
student2 = Student("Bob", 102)

# Adding Students to School
school.add_student(student1)
school.add_student(student2)

# Enrolling Students in Courses
student1.enroll(course1)
student1.enroll(course3)
student2.enroll(course2)

# Displaying Data
school.display_students()
school.display_courses()
student1.display_courses()
student2.display_courses()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 137
#     133                 print(f"- {course.course_name} ({course.course_code})")
#     136 school = school('ABC school')
# --> 137 course1 = Course("Mathematics", "MATH101")
#     138 course2 = Course("Physics", "PHY102")
#     139 course3 = Course("Computer Science", "CS103")
#
# NameError: name 'Course' is not defined
